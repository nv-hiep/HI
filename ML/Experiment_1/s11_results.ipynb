# %% [markdown]
# # Results visualization

# %% [markdown]
# ## packages

# %%
import seaborn as sns
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

# %%
print(os.getcwd())
# Out:
# C:\Users\Administrator-1\Downloads\H2\HI

# %%
sns.set(style = "whitegrid")
#sns.set_theme()("whitegrid", {'axes.grid' : False})

# %% [markdown]
# ## Load data from csv

# %%
csv_path =  os.getcwd()+"\\training_process\\"

# %%
curve = pd.read_csv(csv_path + "curve.csv")
polynomial_0 = pd.read_csv(csv_path+ "polynomial_0.csv")
polynomial_1 = pd.read_csv(csv_path+ "polynomial_1.csv")
Index_PE_Add = pd.read_csv(csv_path+ "index_add.csv")
Index_PE_Concatenate = pd.read_csv(csv_path+ "index_concatenate.csv")
Learnable_PE_Adding = pd.read_csv(csv_path+ "learnable_adding.csv")
No_PE = pd.read_csv(csv_path+"origin.csv")
Sinusoidal_Add = pd.read_csv(csv_path+ "sinusoidal_add.csv")
sinusoidal_PE_concatenate = pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")
spectragram = pd.read_csv(csv_path+ "spectrogram.csv")

# %% [markdown]
# ## Curve

# %%
data = curve.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Indexconcatenate = data[:, 0]
validation_MSE_Indexconcatenate = data[:, 1]
Testing_MSE_Indexconcatenate = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Curve image')
plt.plot(train_MSE_Indexconcatenate, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Indexconcatenate, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Indexconcatenate, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Polynomial with degree of 2 (concatenate in axis 0)

# %% [markdown]
# This method using formula x3 = b + (x2)^2 to calculate the third row and concatenate by 0st axis.
# In here, b is the index positional embedding, x2 is the value of spectra in each velocity.

# %%
data = polynomial_0.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Indexadd = data[:, 0]
validation_MSE_Indexadd = data[:, 1]
Testing_MSE_Indexadd = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Increase dimensionality using Polynomial features (concatenate in 0st axis)')
plt.plot(train_MSE_Indexadd, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Indexadd, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Indexadd, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Polynomial with degree of 2 (concatenate in axis 1)

# %% [markdown]
# This method using formula x3 = b + (x2)^2 to calculate the third row and concatenate by the 1st axis.
# In here, b is the index positional embedding, x2 is the value of spectra in each velocity.

# %%
data = polynomial_1.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_curve = data[:, 0]
validation_MSE_curve = data[:, 1]
Testing_MSE_curve = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Increase dimensionality using Polynomial features (concatenate in 1st axis)')
plt.plot(train_MSE_curve, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_curve, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_curve, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Add index pe positional embedding to original vector

# %% [markdown]
# get positional embedding using index and adding element wise to the original vector

# %%
data = Index_PE_Add.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_spectrogram = data[:, 0]
validation_MSE_spectrogram = data[:, 1]
Testing_MSE_spectrogram = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Index Positional Embedding using Add')
plt.plot(train_MSE_spectrogram, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_spectrogram, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_spectrogram, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Concatenate index positional embedding to original vector

# %% [markdown]
# get positional embedding by index and concatenate in the 1st axis

# %%
data = Index_PE_Concatenate.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Index Positional Embedding Concatenate in 1st axis')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## add learnable positional embedding to original vector

# %% [markdown]
# set positional embedding as learnable parameter and using adding to combine with the original vector

# %%
data = Learnable_PE_Adding.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Learnable Positional Embedding (Adding)')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## original vector

# %% [markdown]
# No positional embedding

# %%
data = No_PE.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('original vector')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Add Sinusoidal positional embedding to original vector

# %% [markdown]
# generate positional embedding using p = sin(x) where x is the index of the spectra vector. Using adding to combine.

# %%
data = Sinusoidal_Add.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Sinusoidal positional embedding (Adding)')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## concatenate sinusoidal positional embedding to original vector in axis 1

# %% [markdown]
# generate positional embedding using p = sin(x) where x is the index of the spectra vector. Using concatenation to combine in the 1st axis.

# %%
data = sinusoidal_PE_concatenate.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Sinusoidal positional embedding (Adding)')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## spectragram

# %% [markdown]
# using Spectragram image as training set

# %%
data = spectragram.to_numpy(copy=True)
data = data[:, 1:]

# %%
train_MSE_Noposition = data[:, 0]
validation_MSE_Noposition = data[:, 1]
Testing_MSE_Noposition = data[:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Sinusoidal positional embedding (Adding)')
plt.plot(train_MSE_Noposition, label='Training_MES')
plt.grid()
plt.plot(validation_MSE_Noposition, label='Vaidation_MSE')
plt.grid()
plt.plot(Testing_MSE_Noposition, label='Tesing_MSE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Training MSE Comparisons

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][:, 0]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][:, 0]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][:, 0]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][:, 0]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][:, 0]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][:, 0]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][:, 0]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][:, 0]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][:, 0]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][:, 0]

# %%
plt.figure(figsize=(7,5))
plt.title('Training MSE Comparison')
plt.plot(curve, label='curve')
plt.grid()
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### focuse on 50+ epoch

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][49:, 0]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][49:, 0]

# %%
plt.figure(figsize=(7,5))
plt.title('Training MSE Comparison (50-80 epeoch)')
plt.plot(curve, label='curve')
plt.grid()
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=8)
plt.show()

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][69:, 0]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][69:, 0]

# %%
plt.figure(figsize=(7,5))
plt.title('Training MSE Comparison (70-80 epeoch)')
plt.plot(polynomial_0, label='polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='learnable_adding')
plt.grid()
plt.plot(No_PE, label='original vector')
plt.grid()
plt.plot(Sinusoidal_Add, label='sinusoidal_add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_concatenate')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=8)
plt.show()

# %% [markdown]
# ## Validation MSE Comparisons

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][:, 1]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][:, 1]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][:, 1]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][:, 1]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][:, 1]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][:, 1]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][:, 1]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][:, 1]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][:, 1]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][:, 1]

# %%
plt.figure(figsize=(7,5))
plt.title('Validation MSE Comparison')
plt.plot(curve, label='curve')
plt.grid()
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
# exclude curve representation
plt.figure(figsize=(7,5))
plt.title('Validation MSE Comparison (exclude curve representation)')
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
#plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### Focuse on 70-80 epoch

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][69:, 1]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][69:, 1]

# %%
plt.figure(figsize=(7,5))
plt.title('validation MSE Comparison (70-80 epeoch )')
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
#plt.grid(start, stop, num=50)
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
#plt.xticks(np.linspace(70, 80, num=10))
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize="small")
plt.show()

# %% [markdown]
# ## Testing MSE Comparisons

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][:, 2]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][:, 2]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][:, 2]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][:, 2]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][:, 2]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][:, 2]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][:, 2]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][:, 2]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][:, 2]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Testing MSE Comparison')
plt.plot(curve, label='curve')
plt.grid()
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=10)
plt.show()

# %%
# no curve 
plt.figure(figsize=(7,5))
plt.title('Testing MSE Comparison (exclude curve representation)')
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
#plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# ### Focuse on 70+ epoch

# %%
curve = (pd.read_csv(csv_path + "curve.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
polynomial_0 = (pd.read_csv(csv_path+ "polynomial_0.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
polynomial_1 = (pd.read_csv(csv_path+ "polynomial_1.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
Index_PE_Add = (pd.read_csv(csv_path+ "index_add.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
Index_PE_Concatenate = (pd.read_csv(csv_path+ "index_concatenate.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
Learnable_PE_Adding = (pd.read_csv(csv_path+ "learnable_adding.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
No_PE = (pd.read_csv(csv_path+"origin.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
Sinusoidal_Add = (pd.read_csv(csv_path+ "sinusoidal_add.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
sinusoidal_PE_concatenate = (pd.read_csv(csv_path+"sinusoidal_concatenate_s1.csv")).to_numpy(copy=True)[:, 1:][69:, 2]
spectragram = (pd.read_csv(csv_path+ "spectrogram.csv")).to_numpy(copy=True)[:, 1:][69:, 2]

# %%
plt.figure(figsize=(7,5))
plt.title('Testing MSE Comparison (70-80 epeoch)')
plt.plot(curve, label='curve')
plt.grid()
plt.plot(polynomial_0, label='Polynomial_feature_0')
plt.grid()
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(Learnable_PE_Adding, label='Learnable_PE_Adding')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.plot(Sinusoidal_Add, label='Sinusoidal_Add')
plt.grid()
plt.plot(sinusoidal_PE_concatenate, label='sinusoidal_PE_concatenate')
plt.plot(spectragram, label='spectragram')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=8)
plt.show()

# %%
# comparing the top 4 representations with minimum MSE in testing
plt.figure(figsize=(7,5))
plt.title('Testing MSE Comparison (70-80 epeoch)')
plt.plot(polynomial_1, label='Polynomial_feature_1')
plt.grid()
plt.plot(Index_PE_Add, label='Index_PE_Add')
plt.grid()
plt.plot(Index_PE_Concatenate, label='Index_PE_Concatenate')
plt.grid()
plt.plot(No_PE, label='No_PE')
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(fontsize=8)
plt.show()
