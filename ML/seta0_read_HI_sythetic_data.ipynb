# %% [markdown]
# <a href="https://colab.research.google.com/github/nv-hiep/HI/blob/main/ML/seta0_read_HI_sythetic_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read data from numerical Simulation

# %% [markdown]
# The raw data are from the numerical Simulation by Seta and Federrath 2022 (https://ui.adsabs.harvard.edu/abs/2022MNRAS.514..957S/abstract)

# %% [markdown]
# # Install packages

# %%
# ! pip install astroML

# %%
# !pip install torch-lr-finder

# %%
! pip install spectral-cube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spectral-cube
#   Downloading spectral_cube-0.6.0-py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.6/218.6 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from spectral-cube) (1.2.0)
# Collecting casa-formats-io
#   Downloading casa_formats_io-0.2.1-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.6/399.6 KB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from spectral-cube) (1.15.0)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from spectral-cube) (1.21.6)
# Collecting radio-beam>=0.3.3
#   Downloading radio_beam-0.3.4-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: dask[array] in /usr/local/lib/python3.8/dist-packages (from spectral-cube) (2022.2.1)
# Requirement already satisfied: astropy in /usr/local/lib/python3.8/dist-packages (from spectral-cube) (4.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from radio-beam>=0.3.3->spectral-cube) (1.7.3)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from astropy->spectral-cube) (2.0.0.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (2022.11.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (21.3)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]->spectral-cube) (2.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->dask[array]->spectral-cube) (3.0.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask[array]->spectral-cube) (1.0.0)
# Installing collected packages: radio-beam, casa-formats-io, spectral-cube
# Successfully installed casa-formats-io-0.2.1 radio-beam-0.3.4 spectral-cube-0.6.0

# %% [markdown]
# # Connect and authorize google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/ML_HI/
# !ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks/ML_HI
# autoencoder_compress.png       lightning_logs
# autoencoder.h5		       MCMC
# autoencoder_no_compress.png    MCMC_
# best_rs_1.pickle	       MLPClassifier_MLPRegressor.ipynb
# best_rs_2.pickle	       MLPRegressor.ipynb
# best_rs_3.pickle	       model.png
# best_rs_chan400_1.pickle       random_weights.h5
# catalogged_verification.fits   rhi_zea.fits
# CNN			       spec64k.npz
# conv_autoencoder.h5	       tigress
# conv_encoder.h5		       training_data_kok14_galfa.pickle
# data			       transforms
# encoder_compress.png	       Untitled.ipynb
# encoder.h5		       vae
# fcnm_zea.fits		       VAE_decoder.h5
# figures			       VAE_encoder.h5
# Find_GNOMES_sightlines.ipynb   VAE.h5
# GNOMES_vs_GALFA_spectra.ipynb  vae_mlp_decoder.png
# libs

# %%
! pwd
# Out:
# /content/gdrive/My Drive/Colab Notebooks/ML_HI

# %% [markdown]
# # Paths

# %%
import sys, os
base_path = os.getcwd()

data_path  = os.path.join(base_path, 'data')
vae_path = os.path.join(base_path, 'vae')
saury_data_path = os.path.join(data_path, 'seta', '')

print(base_path)
print(data_path)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/ML_HI
# /content/gdrive/My Drive/Colab Notebooks/ML_HI/data

# %%
training_data_file = 'Tb_mpism_comp_1200_thick.fits'
rhi_file = 'R_map_mpism_comp_1200.fits'
fcnm_file = 'fcnm_map_mpism_comp_1200_Tcut_500K.fits'

training_data_fits_file = os.path.join(saury_data_path, training_data_file)
training_fcnm_file = os.path.join(saury_data_path, fcnm_file)
training_rhi_file = os.path.join(saury_data_path, rhi_file)

print(training_data_fits_file)
print(training_fcnm_file)
print(training_rhi_file)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/ML_HI/data/seta/Tb_mpism_comp_1200_thick.fits
# /content/gdrive/My Drive/Colab Notebooks/ML_HI/data/seta/fcnm_map_mpism_comp_1200_Tcut_500K.fits
# /content/gdrive/My Drive/Colab Notebooks/ML_HI/data/seta/R_map_mpism_comp_1200.fits

# %% [markdown]
# # Libraries

# %%
sys.path.insert(1, data_path)

from __future__ import print_function, division
from astropy.io          import fits
from astropy             import units as u
from astropy.coordinates import SkyCoord

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import glob
import pickle

# %%
from astropy.wcs import WCS
from spectral_cube import SpectralCube

# %% [markdown]
# # Read training dataset

# %% [markdown]
# Training set is a datacube with a size of (101, 512, 512) includes (512x512) spectra (spectral data: signal strength T_b as a function of 101 wavelength channels) and their ground-truth cold atomic hydrogen gas fraction (FCNM) and opacity correction factor (R). The training dataset was obtained from a simulation.
#
# FCNM range: from ~0. to (less than) 1.
# R range: >= 1

# %% [markdown]
# ![Screenshot 2023-01-20 at 9.57.49 am.png](data:image/png;base64,...)

# %% [markdown]
# **Note:** Atomic Hydrogen Gas = HI

# %%
hdu = fits.open(training_data_fits_file)
data = hdu[0].data

print(data.shape)
# Out:
# (101, 512, 512)

# %% [markdown]
# Position X : 512 bins
#
# Position Y : 512 bins
#
# Velocity Z : 101 channels (in radio astronomy, wavelength [m]/frequency [Hz] is often converted into velocity [VLSR: km/s or m/s].)

# %% [markdown]
# # Total intensity map (or optically-thin HI column density map)

# %% [markdown]
# Position-Position-Velocity (PPV) emission cubes with realistic noise (1K) and beam (30'') for a simulation located at 400pc.

# %%
WHI = np.sum(data, axis=0)
NHI_thin = 1.8224 * 1.e-2 * WHI # In unit of 10^20 cm-2

# %%
plt.figure(figsize=(16,16))
plt.imshow(NHI_thin, cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('Optically-thin N$_\mathrm{HI}$ [10$^{20} cm^{-2}$]', size=16)

plt.title('Total intensity map')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.imshow(np.max(data, axis=0), cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('T$_\mathrm{B}$ max [K]', size=16)

plt.title('')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %% [markdown]
# # Ground-truth cold HI gas fraction

# %% [markdown]
# Each spectrum at (Xi, Yi) has a corresponding ground-truth $F_{CNM}$ at the same sky pixel (Xi, Yi).

# %%
hdu = fits.open(training_fcnm_file)
fcnm_data = hdu[0].data

print(fcnm_data.shape)
# Out:
# (512, 512)

# %%
plt.figure(figsize=(16,16))
plt.imshow(fcnm_data, cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('Cold HI gas fraction F$_\mathrm{CNM}$', size=16)

plt.title('$F_{CNM}$ map')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %% [markdown]
# # Ground-truth opacity correction factor

# %% [markdown]
# Each spectrum at (Xi, Yi) has a corresponding ground-truth $R_{HI}$ at the same sky pixel (Xi, Yi).

# %%
hdu = fits.open(training_rhi_file)
rhi_data = hdu[0].data

print(rhi_data.shape)
# Out:
# (512, 512)

# %%
plt.figure(figsize=(16,16))
plt.imshow(rhi_data, cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('Opacity correction factor R$_\mathrm{HI}$', size=16)

plt.title('R(HI) map')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %% [markdown]
# # Plot a few spectra

# %%
# Spectrum in training set
plt.figure(figsize=(8,6))
plt.plot(data[:, 100, 100], label='data')

plt.title('Training set')
plt.xlabel('Channels')
plt.ylabel('T$_b$ [K]')

plt.legend()

plt.show()

# %%
# Spectrum in training set
plt.figure(figsize=(8,6))
plt.plot(data[:, 20, 100], label='data')

plt.title('Training set')
plt.xlabel('Channels')
plt.ylabel('T$_b$ [K]')

plt.legend()

plt.show()

# %%
# Spectrum in training set
plt.figure(figsize=(8,6))
plt.plot(data[:, 20, 200], label='data')

plt.title('Training set')
plt.xlabel('Channels')
plt.ylabel('T$_b$ [K]')

plt.legend()

plt.show()

# %%
# Spectrum in training set
plt.figure(figsize=(8,6))
plt.plot(data[:, 200, 200], label='data')

plt.title('Training set')
plt.xlabel('Channels')
plt.ylabel('T$_b$ [K]')

plt.legend()

plt.show()

# %% [markdown]
# # Images along the wavelength channels

# %%
plt.figure(figsize=(16,16))
plt.imshow(data[0, :, :], cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('T$_\mathrm{B}$ [K]', size=16)

plt.title('Intensity map at a wavelength channel')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.imshow(data[50, :, :], cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('T$_\mathrm{B}$ [K]', size=16)

plt.title('Intensity map at a wavelength channel')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.imshow(data[100, :, :], cmap='jet')

cbar = plt.colorbar(shrink=0.5, pad=0.005)
cbar.set_label('T$_\mathrm{B}$ [K]', size=16)

plt.title('Intensity map at a wavelength channel')
plt.xlabel('X [channels]')
plt.ylabel('Y [channels]')
plt.show()

# %% [markdown]
# # Histogram of FCNM and R

# %% [markdown]
# **Note:** Atomic Hydrogen Gas = HI

# %%
FCNM = fcnm_data.ravel()
R    = rhi_data.ravel()

# %%
FCNM.shape
# Out:
# (262144,)

# %%
# stats_series = pd.DataFrame(FCNM).describe()
# series_index = stats_series.index.to_list()
# series_values = stats_series.values.flatten()
# print('FCNM:')
# stats_series

# %%
# stats_series = pd.DataFrame(R).describe()
# series_index = stats_series.index.to_list()
# series_values = stats_series.values.flatten()
# print('R:')
# stats_series

# %% [markdown]
# ## Cold HI gas fraction: FCNM

# %%
# Plot histograms
plt.figure(figsize=(10, 6))

plt.hist(FCNM, bins=np.linspace(0., FCNM.max(), 40),
         density=False, color='k', histtype='step',
         alpha=1., ls='-', lw=3,
         label='$F_{CNM}$')

plt.title(f'FCNM')
plt.xlabel(r'CNM fraction ($F_{CNM}$)', fontsize=12)
plt.ylabel(r'#', fontsize=12)
# plt.yscale('log')

plt.legend(loc='upper right', fontsize=14)
plt.show()

# %% [markdown]
# ## HI Opacity correction  Factor : R

# %%
# Plot histograms
plt.figure(figsize=(10, 6))

plt.hist(R, bins=np.linspace(1., R.max(), 40),
         density=False, color='k', histtype='step',
         alpha=1., ls='-', lw=3,
         label='$R_{HI}$')

plt.title('$R_{HI}$')
plt.xlabel(r'$R_{HI}$', fontsize=12)
plt.ylabel(r'#', fontsize=12)
plt.yscale('log')

plt.legend(loc='upper right', fontsize=14)
plt.show()
