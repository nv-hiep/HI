# %% [markdown]
# # NO positional Embedding 10 trials

# %% [markdown]
# ### Original vector with shape of (1, 414)

# %% [markdown]
# ## Libraries

# %%
from __future__ import print_function, division
from astropy.io          import fits
from astropy             import units as u
from astropy.coordinates import SkyCoord
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import OrderedDict
import math

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
from torchsummary import summary
from torchvision import datasets
from torch.optim.lr_scheduler import LambdaLR, StepLR, MultiStepLR, ExponentialLR
import os
import argparse

import glob
import pickle
import Transformer
import data_loader

# %% [markdown]
# # Path

# %%
print(os.getcwd())
# Out:
# C:\Users\Administrator-1\Experiment_2\transformer

# %%
training_data_kok14_galfa = os.path.join(os.getcwd(),"data", "other", "training_data_kok14_galfa.pickle")

# %% [markdown]
# ## Data preparation

# %%
data = pickle.load(open(training_data_kok14_galfa, 'rb'))

# training data
X_train = data['X_train']
Y_train = data['Y_train']
# Observed test data
X_test = data['X_test']
Y_test = data['Y_test']

# %% [markdown]
# ## Split train, validation and testing set from X_train and Y_train with percentages of 60%, 20%, 20%

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train,
                                                    Y_train, 
                                                    test_size=0.2,
                                                    shuffle = True, 
                                                    random_state = 8)

x_train, x_val, y_train, y_val = train_test_split(x_train,
                                                  y_train, 
                                                  test_size=0.25,
                                                  random_state= 8)

# %%
print("x_train=",x_train.shape, ", y_train=", y_train.shape)
print("x_val=",x_val.shape, ", y_val=", y_val.shape)
print("x_test=",x_test.shape, ", y_test=", y_test.shape)
# Out:
# x_train= (23268, 414) , y_train= (23268, 2)
# x_val= (7756, 414) , y_val= (7756, 2)
# x_test= (7757, 414) , y_test= (7757, 2)

# %% [markdown]
# ## Plot a few training samples

# %%
# Spectrum in training set
plt.figure(figsize=(6,4))
plt.plot(X_train[0, :], label=f'Fcnm = {round(Y_train[20000,0], 2)}, R = {round(Y_train[0,1], 2)}')

plt.title('Training set')
plt.xlabel('Velocity')
plt.ylabel('T$_b$ [K]')
plt.legend()
plt.show()

# %%
# Spectrum in training set
plt.figure(figsize=(6,4))
plt.plot(X_train[1000, :], label=f'Fcnm = {round(Y_train[10000,0], 2)}, R = {round(Y_train[10000,1], 2)}')
plt.title('Training set')
plt.xlabel('Velocity')
plt.ylabel('T$_b$ [K]')
plt.legend()
plt.show()

# %% [markdown]
# ## Data loader

# %%
# initialize dataset
dataset_train = data_loader.spectra_loader(x_train,
                                           y_train,
                                           transform=data_loader.ToTensor(),
                                           target_transform=data_loader.ToTensor(), 
                                           pe=None)

dataset_val = data_loader.spectra_loader(x_val,
                                         y_val,
                                         transform=data_loader.ToTensor(),
                                         target_transform=data_loader.ToTensor(),
                                         pe=None)

dataset_test = data_loader.spectra_loader(x_test, 
                                          y_test,
                                          transform=data_loader.ToTensor(), 
                                          target_transform=data_loader.ToTensor(),
                                          pe=None)

# %%
# initialize data loader
batch_size = 20 
train_loader = torch.utils.data.DataLoader(dataset = dataset_train, 
                                           batch_size = batch_size, 
                                           shuffle =True)

valid_loader = torch.utils.data.DataLoader(dataset = dataset_val,
                                           batch_size = batch_size, 
                                           shuffle =False)

test_loader = torch.utils.data.DataLoader(dataset = dataset_test, 
                                          batch_size = batch_size, 
                                          shuffle =False)

# %%
# test data loader
val = iter(test_loader)
A,B = next(val)
print(A.shape)
print(B.shape)
# Out:
# torch.Size([20, 1, 1, 414])
# torch.Size([20, 2])

# %% [markdown]
# ## Model Training and Evaluation

# %%
# train 
def train(epoch):
    """
    Train the model.
    Parameters
    ----------
    epoch : int.
        the index of epoch.

    Returns
    -------
    train_loss/total: The mean MSE in an epoch.     
    """
    model.train()
    train_loss = 0
    total = 0
    for index, (inputs, values) in enumerate(train_loader):
        inputs = inputs.float()
        values = values.float()
        inputs, values = inputs.to(device), values.to(device)
        # forward
        outputs = model(inputs)
        loss = loss_function(outputs, values)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # print info
        train_loss = train_loss + (loss.item()*values.size(0)) 
        total += values.size(0)
    print("total loss=",train_loss)
    return train_loss/total

# %%
def validation(epoch):
    """
    validate the model.
    Parameters
    ----------
    epoch : int.
        the index of epoch.

    Returns
    -------
    error: The mean MSE in validation set. 
        
    """
    model.eval()
    global best_err
    test_loss = 0
    total = 0
    with torch.no_grad():
        for index, (inputs, values) in enumerate(valid_loader):
            inputs = inputs.float()
            values = values.float()
            inputs, values = inputs.to(device), values.to(device)
            # forward
            outputs = model(inputs)
            loss = loss_function(outputs, values)
            test_loss = test_loss + (loss.item()*values.size(0))
            total += values.size(0)
    # Save checkpoint.
    error =  test_loss / total
    print(f"validation MSE in epoch {epoch}= ", error)
    if error < best_err:
        print('best_err:', error, 'Saving..')
        state = {'net': model.state_dict(),
                 'err': error,
                 'optimizer_state_dict': optimizer.state_dict(),
                 'epoch': epoch}
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/s2_no_pe.pth')
        best_err = error
    return error

# %%
def test(epoch):
    """
    test the model.
    Parameters
    ----------
    epoch : int.
        the index of epoch.
    Returns
    -------
    error: The mean MSE in test set. 
    """
    model.eval()
    global best_err
    test_loss = 0
    total = 0
    with torch.no_grad():
        for index, (inputs, values) in enumerate(test_loader):
            inputs = inputs.float()
            values = values.float()
            inputs, values = inputs.to(device), values.to(device)
            # forward 
            outputs = model(inputs)
            #outputs = outputs.view(outputs[0], 1, outputs[1])
            loss = loss_function(outputs, values)
            test_loss =test_loss+ (loss.item()* values.size(0))
            total += values.size(0)
        #print(f'Test performance in epoch {epoch}: avg_error = {test_loss/total}')
        return test_loss/total

# %% [markdown]
# ## Training: 10 trails

# %%
# define number of trails, number of epoch and learning rate
num_trial = 10
num_epoch = 80
learning_rate = 0.005
# the savier of best validation performance and coresponding testing performance.
vali = []
testing = []
# saver for each trials
train_trails = []
validate_trails =[]
test_trails = []

# %%
def trail(num_epoch):
    global vali
    global testing
    global scheduler
    global model
    global lr
    #define savor
    global train_trails
    global validate_trails
    global test_trails
    for epoch in range(num_epoch):
        train_err = train(epoch)
        vali_err = validation(epoch)
        scheduler.step()
        test_err = test(epoch)
        # save data
        train_trails.append(train_err)
        validate_trails.append(vali_err)
        test_trails.append(test_err)
    # final test
    validation_error,test_error = validate_model()
    print("test err=",test_error)
    vali.append(validation_error)
    testing.append(test_error)

# %%
def validate_model():
    global model
    model = Transformer.Transformer(num_output=2, 
                                    in_channels=1, 
                                    input_row=1, 
                                    input_column=414,
                                    ipe=False)
    num_step = len(X_train)/batch_size
    loss_function = nn.MSELoss()
    best_err = 100000
    checkpoint = torch.load('./checkpoint/s2_no_pe.pth',map_location=torch.device('cuda:0'))
    model.load_state_dict(checkpoint['net'])
    model.to(device)
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    validation_error = validation(epoch)
    test_error = test(epoch)
    return validation_error, test_error

# %%
# start 10 trails.
for i in range (0, num_trial):
    print(f'start the {i}th trial:')
    # model initialization
    lr=learning_rate
    model = Transformer.Transformer(num_output=2, 
                                    in_channels=1, 
                                    input_row=1, 
                                    input_column=414,
                                    ipe=False)
    num_step = len(X_train)/batch_size
    loss_function = nn.MSELoss()
    best_err = 100000
    optimizer = torch.optim.SGD(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer=optimizer, 
                                                     milestones = [65], 
                                                     gamma=0.1, last_epoch=-1, 
                                                     verbose=False)
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    trail(num_epoch)
# Out:
# start the 0th trial:
# total loss= 713.4630674384534
# validation MSE in epoch 0=  0.026274274981831876
# best_err: 0.026274274981831876 Saving..
# total loss= 342.27194371446967
# validation MSE in epoch 1=  0.011246320944641586
# best_err: 0.011246320944641586 Saving..
# total loss= 300.9206439484842
# validation MSE in epoch 2=  0.010193884675907353
# best_err: 0.010193884675907353 Saving..
# total loss= 283.5016303155571
# validation MSE in epoch 3=  0.013874312110707287
# total loss= 264.14112265827134
# validation MSE in epoch 4=  0.011896311608539408
# total loss= 256.4141721390188
# validation MSE in epoch 5=  0.009806108073575895
# best_err: 0.009806108073575895 Saving..
# total loss= 252.70220961840823
# validation MSE in epoch 6=  0.009128215300426457
# best_err: 0.009128215300426457 Saving..
# total loss= 244.47793462174013
# validation MSE in epoch 7=  0.009317928899039695
# total loss= 238.3299087989144
# validation MSE in epoch 8=  0.010389503598541728
# total loss= 237.40010934136808
# validation MSE in epoch 9=  0.010417595359459788
# total loss= 233.5087697491981
# validation MSE in epoch 10=  0.012368390208990143
# total loss= 228.79026719694957
# validation MSE in epoch 11=  0.009756557155537884
# total loss= 227.05034871399403
# validation MSE in epoch 12=  0.008912158218167276
# best_err: 0.008912158218167276 Saving..
# total loss= 224.9021183140576
# validation MSE in epoch 13=  0.008741095480739652
# best_err: 0.008741095480739652 Saving..
# total loss= 223.00400203140453
# validation MSE in epoch 14=  0.009140668671276534
# total loss= 219.34524338133633
# validation MSE in epoch 15=  0.014790081214678463
# total loss= 218.01588695403188
# validation MSE in epoch 16=  0.009615390729960035
# total loss= 217.34197879536077
# validation MSE in epoch 17=  0.00850920772944616
# best_err: 0.00850920772944616 Saving..
# total loss= 215.5632833004929
# validation MSE in epoch 18=  0.010552613229153159
# total loss= 213.94054986559786
# validation MSE in epoch 19=  0.008427829625094122
# best_err: 0.008427829625094122 Saving..
# total loss= 214.2530338591896
# validation MSE in epoch 20=  0.008466336988486626
# total loss= 213.1151112425141
# validation MSE in epoch 21=  0.009405573754479639
# total loss= 212.19739251583815
# validation MSE in epoch 22=  0.009761169102151464
# total loss= 212.37430102191865
# validation MSE in epoch 23=  0.011204381470720736
# total loss= 210.47353857476264
# validation MSE in epoch 24=  0.008610064043246051
# total loss= 211.72701283171773
# validation MSE in epoch 25=  0.012028790394141078
# total loss= 210.62102640839294
# validation MSE in epoch 26=  0.009109017576555451
# total loss= 208.2981728487648
# validation MSE in epoch 27=  0.009435656725209497
# total loss= 207.5041579878889
# validation MSE in epoch 28=  0.012400467210997313
# total loss= 207.63770853355527
# validation MSE in epoch 29=  0.008370265725600451
# best_err: 0.008370265725600451 Saving..
# total loss= 205.78309239353985
# validation MSE in epoch 30=  0.008606666713040908
# total loss= 205.91223678947426
# validation MSE in epoch 31=  0.009072304674476585
# total loss= 204.8015305623412
# validation MSE in epoch 32=  0.01168958217918089
# total loss= 204.12201758753508
# validation MSE in epoch 33=  0.008548737251695223
# total loss= 204.67488266341388
# validation MSE in epoch 34=  0.008607095065018736
# total loss= 203.67211776133627
# validation MSE in epoch 35=  0.008573758939056321
# total loss= 203.95991767314263
# validation MSE in epoch 36=  0.010478526693415771
# total loss= 202.59934478788637
# validation MSE in epoch 37=  0.00988687292272595
# total loss= 202.3781224875711
# validation MSE in epoch 38=  0.008417359808802819
# total loss= 202.55374656617641
# validation MSE in epoch 39=  0.010103366087954981
# total loss= 200.6016220417805
# validation MSE in epoch 40=  0.01008845348137586
# total loss= 200.93862018967047
# validation MSE in epoch 41=  0.008222534309120684
# best_err: 0.008222534309120684 Saving..
# total loss= 200.56724879192188
# validation MSE in epoch 42=  0.00833361872645141
# total loss= 202.21112030325457
# validation MSE in epoch 43=  0.008196486930217345
# best_err: 0.008196486930217345 Saving..
# total loss= 200.3459111736156
# validation MSE in epoch 44=  0.008865270958341612
# total loss= 199.6064816354774
# validation MSE in epoch 45=  0.008437865813103778
# total loss= 199.55379199190065
# validation MSE in epoch 46=  0.008997792764117747
# total loss= 200.24101231060922
# validation MSE in epoch 47=  0.008090591261006292
# best_err: 0.008090591261006292 Saving..
# total loss= 199.72339460579678
# validation MSE in epoch 48=  0.008343530251002616
# total loss= 199.08194982795976
# validation MSE in epoch 49=  0.008102955692111504
# total loss= 198.23438772698864
# validation MSE in epoch 50=  0.008032804384024053
# best_err: 0.008032804384024053 Saving..
# total loss= 197.4040202407632
# validation MSE in epoch 51=  0.00828421093985081
# total loss= 197.53526787739247
# validation MSE in epoch 52=  0.008060213893999227
# total loss= 197.5001997090876
# validation MSE in epoch 53=  0.008162536430559272
# total loss= 196.70130082732067
# validation MSE in epoch 54=  0.008234533919823607
# total loss= 196.7968529984355
# validation MSE in epoch 55=  0.013251005498045894
# total loss= 196.57215053844266
# validation MSE in epoch 56=  0.007996176435711086
# best_err: 0.007996176435711086 Saving..
# total loss= 195.7930862014182
# validation MSE in epoch 57=  0.008009057011827058
# total loss= 195.79613571590744
# validation MSE in epoch 58=  0.013204773998463381
# total loss= 195.6371133509092
# validation MSE in epoch 59=  0.008285349611742418
# total loss= 195.3057263349183
# validation MSE in epoch 60=  0.008743740964082683
# total loss= 195.37839799327776
# validation MSE in epoch 61=  0.007957451028642237
# best_err: 0.007957451028642237 Saving..
# total loss= 194.3086639342364
# validation MSE in epoch 62=  0.007944710214553634
# best_err: 0.007944710214553634 Saving..
# total loss= 194.59701158106327
# validation MSE in epoch 63=  0.00793729254761216
# best_err: 0.00793729254761216 Saving..
# total loss= 194.07715832116082
# validation MSE in epoch 64=  0.009159735105681997
# total loss= 188.0324764396064
# validation MSE in epoch 65=  0.007901961163388562
# best_err: 0.007901961163388562 Saving..
# total loss= 187.79604257829487
# validation MSE in epoch 66=  0.007920533075533392
# total loss= 187.8143011832144
# validation MSE in epoch 67=  0.0078944849223691
# best_err: 0.0078944849223691 Saving..
# total loss= 187.67891300935298
# validation MSE in epoch 68=  0.007934403350654089
# total loss= 187.7767559303902
# validation MSE in epoch 69=  0.007895358204911258
# total loss= 187.78510335832834
# validation MSE in epoch 70=  0.007897255878944513
# total loss= 187.6766342916526
# validation MSE in epoch 71=  0.007917698473278615
# total loss= 187.6774068530649
# validation MSE in epoch 72=  0.007886601432875978
# best_err: 0.007886601432875978 Saving..
# total loss= 187.60540841845796
# validation MSE in epoch 73=  0.007903822831045347
# total loss= 187.6428996748291
# validation MSE in epoch 74=  0.007889511933357634
# total loss= 187.43664755299687
# validation MSE in epoch 75=  0.007926682213884732
# total loss= 187.58333277935162
# validation MSE in epoch 76=  0.007893865647192135
# total loss= 187.5316282743588
# validation MSE in epoch 77=  0.007916866058398225
# total loss= 187.5578813215252
# validation MSE in epoch 78=  0.007884595821546261
# best_err: 0.007884595821546261 Saving..
# total loss= 187.52233852958307
# validation MSE in epoch 79=  0.007929899624240013
# validation MSE in epoch 78=  0.007884595821546261
# test err= 0.008085904033924
# start the 1th trial:
# total loss= 744.6502244723961
# validation MSE in epoch 0=  0.01662268340931038
# best_err: 0.01662268340931038 Saving..
# total loss= 379.4499643081799
# validation MSE in epoch 1=  0.012008667375475492
# best_err: 0.012008667375475492 Saving..
# total loss= 336.0622194306925
# validation MSE in epoch 2=  0.01443046605338877
# total loss= 307.70257201232016
# validation MSE in epoch 3=  0.013666204557849681
# total loss= 295.31182815600187
# validation MSE in epoch 4=  0.03260494081583018
# total loss= 278.83726761024445
# validation MSE in epoch 5=  0.012281463962757231
# total loss= 273.9941596807912
# validation MSE in epoch 6=  0.01176720955315449
# best_err: 0.01176720955315449 Saving..
# total loss= 268.8029190003872
# validation MSE in epoch 7=  0.014076456172769296
# total loss= 262.9433304173872
# validation MSE in epoch 8=  0.011420302534434617
# best_err: 0.011420302534434617 Saving..
# total loss= 257.3658210784197
# validation MSE in epoch 9=  0.012492797375056756
# total loss= 253.6747993803583
# validation MSE in epoch 10=  0.012403305205326794
# total loss= 250.61344526335597
# validation MSE in epoch 11=  0.010234372071499633
# best_err: 0.010234372071499633 Saving..
# total loss= 245.98065537773073
# validation MSE in epoch 12=  0.010246904400156166
# total loss= 240.50242881057784
# validation MSE in epoch 13=  0.01104683642098637
# total loss= 239.8512440547347
# validation MSE in epoch 14=  0.01306256360293699
# total loss= 238.28965252125636
# validation MSE in epoch 15=  0.009620515233632936
# best_err: 0.009620515233632936 Saving..
# total loss= 235.63288363441825
# validation MSE in epoch 16=  0.009754403557759517
# total loss= 234.4573704614304
# validation MSE in epoch 17=  0.009610392517338652
# best_err: 0.009610392517338652 Saving..
# total loss= 231.92356146220118
# validation MSE in epoch 18=  0.011771733044296533
# total loss= 230.64085402712226
# validation MSE in epoch 19=  0.010230412978228411
# total loss= 228.15208972385153
# validation MSE in epoch 20=  0.009165456558756873
# best_err: 0.009165456558756873 Saving..
# total loss= 227.88543176883832
# validation MSE in epoch 21=  0.009859659487252854
# total loss= 228.15764572145417
# validation MSE in epoch 22=  0.009114587060624927
# best_err: 0.009114587060624927 Saving..
# total loss= 224.26268995041028
# validation MSE in epoch 23=  0.010392678936855995
# total loss= 223.61674523586407
# validation MSE in epoch 24=  0.008827091687608197
# best_err: 0.008827091687608197 Saving..
# total loss= 224.81151432031766
# validation MSE in epoch 25=  0.009919063613510845
# total loss= 222.79143498418853
# validation MSE in epoch 26=  0.00981680563624128
# total loss= 220.94895714428276
# validation MSE in epoch 27=  0.01232762690662354
# total loss= 219.75560194207355
# validation MSE in epoch 28=  0.008756567847789153
# best_err: 0.008756567847789153 Saving..
# total loss= 220.33474390534684
# validation MSE in epoch 29=  0.009207531305300403
# total loss= 219.71987691009417
# validation MSE in epoch 30=  0.008696746977673898
# best_err: 0.008696746977673898 Saving..
# total loss= 218.56147367879748
# validation MSE in epoch 31=  0.00868443540777039
# best_err: 0.00868443540777039 Saving..
# total loss= 218.40612008981407
# validation MSE in epoch 32=  0.008914025542684103
# total loss= 217.10166043415666
# validation MSE in epoch 33=  0.009909560761074408
# total loss= 217.307921317406
# validation MSE in epoch 34=  0.008722779578375599
# total loss= 216.396208377555
# validation MSE in epoch 35=  0.008577759026611237
# best_err: 0.008577759026611237 Saving..
# total loss= 215.34892567293718
# validation MSE in epoch 36=  0.012346046648933032
# total loss= 215.8526387871243
# validation MSE in epoch 37=  0.009442954978849422
# total loss= 213.8295903003309
# validation MSE in epoch 38=  0.009517544693788566
# total loss= 212.97049511224031
# validation MSE in epoch 39=  0.00944391567494899
# total loss= 212.95434308424592
# validation MSE in epoch 40=  0.009499647689655676
# total loss= 212.94613357726485
# validation MSE in epoch 41=  0.010786888285615933
# total loss= 211.9401084780693
# validation MSE in epoch 42=  0.00852547577276582
# best_err: 0.00852547577276582 Saving..
# total loss= 211.0458246669732
# validation MSE in epoch 43=  0.008578322608674223
# total loss= 210.8546178820543
# validation MSE in epoch 44=  0.008527726698916573
# total loss= 211.52170732337981
# validation MSE in epoch 45=  0.009846595029503706
# total loss= 210.743693836499
# validation MSE in epoch 46=  0.00853671056542415
# total loss= 209.49481822224334
# validation MSE in epoch 47=  0.009196491442263402
# total loss= 209.97440028563142
# validation MSE in epoch 48=  0.008542165646073517
# total loss= 209.11910586385056
# validation MSE in epoch 49=  0.009841282806724748
# total loss= 209.27543432614766
# validation MSE in epoch 50=  0.00948251763194446
# total loss= 208.87283088080585
# validation MSE in epoch 51=  0.00844742608825326
# best_err: 0.00844742608825326 Saving..
# total loss= 209.23531293030828
# validation MSE in epoch 52=  0.008375336091255538
# best_err: 0.008375336091255538 Saving..
# total loss= 208.4099346883595
# validation MSE in epoch 53=  0.008334882622534267
# best_err: 0.008334882622534267 Saving..
# total loss= 207.97645812574774
# validation MSE in epoch 54=  0.008439386965463907
# total loss= 207.42938364529982
# validation MSE in epoch 55=  0.00856126049698473
# total loss= 207.04612622968853
# validation MSE in epoch 56=  0.0090699373550983
# total loss= 206.56619799416512
# validation MSE in epoch 57=  0.008643063236489775
# total loss= 206.80391423264518
# validation MSE in epoch 58=  0.00879880358576568
# total loss= 206.5143723739311
# validation MSE in epoch 59=  0.008477055281484736
# total loss= 206.09958115266636
# validation MSE in epoch 60=  0.008765168456985582
# total loss= 205.79943780554458
# validation MSE in epoch 61=  0.008290068620045934
# best_err: 0.008290068620045934 Saving..
# total loss= 205.30233119381592
# validation MSE in epoch 62=  0.00830746270800725
# total loss= 205.29156869556755
# validation MSE in epoch 63=  0.00838069220909502
# total loss= 205.49884998705238
# validation MSE in epoch 64=  0.008747018203357847
# total loss= 200.2217965722084
# validation MSE in epoch 65=  0.00824108101683801
# best_err: 0.00824108101683801 Saving..
# total loss= 200.11219931440428
# validation MSE in epoch 66=  0.008258386461826472
# total loss= 200.06011024303734
# validation MSE in epoch 67=  0.008243050787738626
# total loss= 200.03497815644369
# validation MSE in epoch 68=  0.008242080331784338
# total loss= 199.89911756431684
# validation MSE in epoch 69=  0.008256708647104297
# total loss= 199.9823219543323
# validation MSE in epoch 70=  0.008267522462806508
# total loss= 199.98814634606242
# validation MSE in epoch 71=  0.008238286750601021
# best_err: 0.008238286750601021 Saving..
# total loss= 199.9576994101517
# validation MSE in epoch 72=  0.008239031845524564
# total loss= 199.91880405228585
# validation MSE in epoch 73=  0.008394376816366842
# total loss= 199.84253112599254
# validation MSE in epoch 74=  0.008404252131850434
# total loss= 199.88990835333243
# validation MSE in epoch 75=  0.008248457257876526
# total loss= 199.88571958057582
# validation MSE in epoch 76=  0.008238008195513215
# best_err: 0.008238008195513215 Saving..
# total loss= 199.86661621462554
# validation MSE in epoch 77=  0.008264156772232509
# total loss= 199.85160698834807
# validation MSE in epoch 78=  0.0082648506043085
# total loss= 199.8730176135432
# validation MSE in epoch 79=  0.00825056482639352
# validation MSE in epoch 76=  0.008238008195513215
# test err= 0.00855161325168741
# start the 2th trial:
# total loss= 771.7335339998826
# validation MSE in epoch 0=  0.019619798109553995
# best_err: 0.019619798109553995 Saving..
# total loss= 430.4637989643961
# validation MSE in epoch 1=  0.012925321581836381
# best_err: 0.012925321581836381 Saving..
# total loss= 377.570076177828
# validation MSE in epoch 2=  0.016608762535852077
# total loss= 353.55556266894564
# validation MSE in epoch 3=  0.016409854937773225
# total loss= 304.9221646031365
# validation MSE in epoch 4=  0.012526484531008932
# best_err: 0.012526484531008932 Saving..
# total loss= 292.8463261201978
# validation MSE in epoch 5=  0.012154239644606268
# best_err: 0.012154239644606268 Saving..
# total loss= 292.409452510532
# validation MSE in epoch 6=  0.03533308395886311
# total loss= 285.42785558104515
# validation MSE in epoch 7=  0.011462822754143547
# best_err: 0.011462822754143547 Saving..
# total loss= 271.91193990269676
# validation MSE in epoch 8=  0.011498352965049911
# total loss= 265.7181716328487
# validation MSE in epoch 9=  0.013709269576888991
# total loss= 262.644196389243
# validation MSE in epoch 10=  0.009275353678704834
# best_err: 0.009275353678704834 Saving..
# total loss= 255.00990392034873
# validation MSE in epoch 11=  0.010958792484457143
# total loss= 249.49801490223035
# validation MSE in epoch 12=  0.009219549076133102
# best_err: 0.009219549076133102 Saving..
# total loss= 247.8867330425419
# validation MSE in epoch 13=  0.009581350133158247
# total loss= 244.17254257155582
# validation MSE in epoch 14=  0.00916938290972351
# best_err: 0.00916938290972351 Saving..
# total loss= 240.45446602907032
# validation MSE in epoch 15=  0.00919006206911747
# total loss= 239.64452655613422
# validation MSE in epoch 16=  0.009874712812218118
# total loss= 236.32931949663907
# validation MSE in epoch 17=  0.010043108825009391
# total loss= 234.2481763237156
# validation MSE in epoch 18=  0.009213526763118969
# total loss= 233.35533290402964
# validation MSE in epoch 19=  0.010309188878269364
# total loss= 231.90114151826128
# validation MSE in epoch 20=  0.008727797256341246
# best_err: 0.008727797256341246 Saving..
# total loss= 230.0172985997051
# validation MSE in epoch 21=  0.010008649643469274
# total loss= 225.3338392530568
# validation MSE in epoch 22=  0.008752665346533507
# total loss= 226.54289364488795
# validation MSE in epoch 23=  0.009376645286203914
# total loss= 226.89729717886075
# validation MSE in epoch 24=  0.009677350469214084
# total loss= 225.50269651087
# validation MSE in epoch 25=  0.009832813670772765
# total loss= 223.26405239664018
# validation MSE in epoch 26=  0.008448654866804739
# best_err: 0.008448654866804739 Saving..
# total loss= 222.09250646224245
# validation MSE in epoch 27=  0.010584833419844777
# total loss= 220.4972371174954
# validation MSE in epoch 28=  0.009845065229388397
# total loss= 219.86084995931014
# validation MSE in epoch 29=  0.009608831529084318
# total loss= 219.36971046309918
# validation MSE in epoch 30=  0.009311343056916837
# total loss= 217.1203957661055
# validation MSE in epoch 31=  0.018396606696207633
# total loss= 218.87262909766287
# validation MSE in epoch 32=  0.008301904434571163
# best_err: 0.008301904434571163 Saving..
# total loss= 217.16762625053525
# validation MSE in epoch 33=  0.009821335626828525
# total loss= 215.37092021666467
# validation MSE in epoch 34=  0.008550661522847067
# total loss= 215.13134693866596
# validation MSE in epoch 35=  0.008214548544294445
# best_err: 0.008214548544294445 Saving..
# total loss= 213.67445938196033
# validation MSE in epoch 36=  0.008544931673579776
# total loss= 213.6677989596501
# validation MSE in epoch 37=  0.008430705750514784
# total loss= 212.58896847767755
# validation MSE in epoch 38=  0.008494231471363906
# total loss= 213.42415085202083
# validation MSE in epoch 39=  0.00857581273204003
# total loss= 212.08393086725846
# validation MSE in epoch 40=  0.011320984435794648
# total loss= 212.57597428699955
# validation MSE in epoch 41=  0.011461850625567057
# total loss= 210.36964209470898
# validation MSE in epoch 42=  0.009365656012918968
# total loss= 209.98112964676693
# validation MSE in epoch 43=  0.008582236339175299
# total loss= 208.6560041604098
# validation MSE in epoch 44=  0.008638966313991725
# total loss= 207.503026119899
# validation MSE in epoch 45=  0.010152548298075442
# total loss= 207.28238826058805
# validation MSE in epoch 46=  0.009887788972138682
# total loss= 206.2702172291465
# validation MSE in epoch 47=  0.009917999637328076
# total loss= 207.12766476767138
# validation MSE in epoch 48=  0.008346367629723793
# total loss= 207.68158472166397
# validation MSE in epoch 49=  0.010495832638767974
# total loss= 207.0389807461761
# validation MSE in epoch 50=  0.008023240163481864
# best_err: 0.008023240163481864 Saving..
# total loss= 205.64484562445432
# validation MSE in epoch 51=  0.009989437266457547
# total loss= 206.46476773405448
# validation MSE in epoch 52=  0.008592696963039012
# total loss= 205.70410808967426
# validation MSE in epoch 53=  0.008456652108056335
# total loss= 205.2105172383599
# validation MSE in epoch 54=  0.010020329340004668
# total loss= 204.5918809985742
# validation MSE in epoch 55=  0.008062242497805296
# total loss= 204.7132767494768
# validation MSE in epoch 56=  0.008096423095499001
# total loss= 204.14452354889363
# validation MSE in epoch 57=  0.00846656172115081
# total loss= 203.5244517121464
# validation MSE in epoch 58=  0.008158839325016617
# total loss= 203.3886706281919
# validation MSE in epoch 59=  0.00861784918358633
# total loss= 203.23368543572724
# validation MSE in epoch 60=  0.008040104448915876
# total loss= 203.56386678526178
# validation MSE in epoch 61=  0.00801434891379826
# best_err: 0.00801434891379826 Saving..
# total loss= 201.66055136709474
# validation MSE in epoch 62=  0.009338905015907981
# total loss= 202.33356760907918
# validation MSE in epoch 63=  0.008079255178012145
# total loss= 202.31333799147978
# validation MSE in epoch 64=  0.009170432239069635
# total loss= 193.66794710000977
# validation MSE in epoch 65=  0.007935011439333282
# best_err: 0.007935011439333282 Saving..
# total loss= 193.3788105980493
# validation MSE in epoch 66=  0.007911756868563524
# best_err: 0.007911756868563524 Saving..
# total loss= 193.3609238206409
# validation MSE in epoch 67=  0.007980140675660923
# total loss= 193.43999613821507
# validation MSE in epoch 68=  0.007901345229613518
# best_err: 0.007901345229613518 Saving..
# total loss= 193.2400502571836
# validation MSE in epoch 69=  0.00790694805553549
# total loss= 193.34654840221629
# validation MSE in epoch 70=  0.007904756772694529
# total loss= 193.09400931489654
# validation MSE in epoch 71=  0.007928474783134186
# total loss= 193.2699396489188
# validation MSE in epoch 72=  0.00790810919246219
# total loss= 193.2919216970913
# validation MSE in epoch 73=  0.007909261564978232
# total loss= 193.10601355694234
# validation MSE in epoch 74=  0.007901950638879104
# total loss= 193.25021197646856
# validation MSE in epoch 75=  0.007898336873078058
# best_err: 0.007898336873078058 Saving..
# total loss= 193.15540907671675
# validation MSE in epoch 76=  0.00800520172121715
# total loss= 193.08609512681141
# validation MSE in epoch 77=  0.007919343407786978
# total loss= 193.18411464313976
# validation MSE in epoch 78=  0.007902306738218784
# total loss= 193.08776645129547
# validation MSE in epoch 79=  0.007899631543001885
# validation MSE in epoch 75=  0.007898336873078058
# test err= 0.00821976548296577
# start the 3th trial:
# total loss= 819.7812398727983
# validation MSE in epoch 0=  0.05645207179275107
# best_err: 0.05645207179275107 Saving..
# total loss= 403.2843140559271
# validation MSE in epoch 1=  0.03153727122771258
# best_err: 0.03153727122771258 Saving..
# total loss= 360.3862652136013
# validation MSE in epoch 2=  0.01116066818800863
# best_err: 0.01116066818800863 Saving..
# total loss= 326.3213334782049
# validation MSE in epoch 3=  0.012236091907483407
# total loss= 303.2139882268384
# validation MSE in epoch 4=  0.010314098980552515
# best_err: 0.010314098980552515 Saving..
# total loss= 292.36953195557
# validation MSE in epoch 5=  0.011969301034516284
# total loss= 288.4576838687062
# validation MSE in epoch 6=  0.009766982308271437
# best_err: 0.009766982308271437 Saving..
# total loss= 274.969909530133
# validation MSE in epoch 7=  0.009625800796522692
# best_err: 0.009625800796522692 Saving..
# total loss= 266.8532675737515
# validation MSE in epoch 8=  0.011579576810394895
# total loss= 265.81946958974004
# validation MSE in epoch 9=  0.012887089116745708
# total loss= 256.8401454091072
# validation MSE in epoch 10=  0.011377013125973204
# total loss= 258.73758742259815
# validation MSE in epoch 11=  0.009516832147124057
# best_err: 0.009516832147124057 Saving..
# total loss= 249.70385719230399
# validation MSE in epoch 12=  0.00922497957471764
# best_err: 0.00922497957471764 Saving..
# total loss= 248.87177873356268
# validation MSE in epoch 13=  0.01467411294810055
# total loss= 248.37107197288424
# validation MSE in epoch 14=  0.009233793549243478
# total loss= 243.73016062146053
# validation MSE in epoch 15=  0.009935149948183272
# total loss= 240.08614048548043
# validation MSE in epoch 16=  0.014245396295645
# total loss= 238.45408648485318
# validation MSE in epoch 17=  0.011569341390320186
# total loss= 237.15672690887004
# validation MSE in epoch 18=  0.008948588680765097
# best_err: 0.008948588680765097 Saving..
# total loss= 233.14389558741823
# validation MSE in epoch 19=  0.010399783432472626
# total loss= 234.5254553644918
# validation MSE in epoch 20=  0.010016841280897056
# total loss= 233.16613844688982
# validation MSE in epoch 21=  0.011132217110989615
# total loss= 231.63791006663814
# validation MSE in epoch 22=  0.008752329738511906
# best_err: 0.008752329738511906 Saving..
# total loss= 230.29025389393792
# validation MSE in epoch 23=  0.008774102111835736
# total loss= 228.58105258829892
# validation MSE in epoch 24=  0.01282910376430795
# total loss= 226.56710410304368
# validation MSE in epoch 25=  0.009148054383623079
# total loss= 224.18800315726548
# validation MSE in epoch 26=  0.027699480193958664
# total loss= 225.22387162828818
# validation MSE in epoch 27=  0.009284504191554188
# total loss= 224.31176911247894
# validation MSE in epoch 28=  0.009300668763506882
# total loss= 223.43269636388868
# validation MSE in epoch 29=  0.009464523384093954
# total loss= 223.59879194339737
# validation MSE in epoch 30=  0.00872293481175308
# best_err: 0.00872293481175308 Saving..
# total loss= 221.6772685381584
# validation MSE in epoch 31=  0.009293536439224839
# total loss= 221.58186055719852
# validation MSE in epoch 32=  0.009666890562334265
# total loss= 220.66295544803143
# validation MSE in epoch 33=  0.010765677801409737
# total loss= 218.36543972743675
# validation MSE in epoch 34=  0.009084296351166124
# total loss= 218.36700879130512
# validation MSE in epoch 35=  0.008635027528199635
# best_err: 0.008635027528199635 Saving..
# total loss= 218.395831159316
# validation MSE in epoch 36=  0.00975145423297817
# total loss= 217.94792407611385
# validation MSE in epoch 37=  0.008632522664328748
# best_err: 0.008632522664328748 Saving..
# total loss= 217.1059340951033
# validation MSE in epoch 38=  0.009078904644880577
# total loss= 216.19407511176541
# validation MSE in epoch 39=  0.011883888367223426
# total loss= 215.21839919127524
# validation MSE in epoch 40=  0.008552720048903117
# best_err: 0.008552720048903117 Saving..
# total loss= 215.50052692135796
# validation MSE in epoch 41=  0.01045740061860326
# total loss= 215.98469294887036
# validation MSE in epoch 42=  0.008693340277206104
# total loss= 213.69972178642638
# validation MSE in epoch 43=  0.008566936994352833
# total loss= 214.64367114566267
# validation MSE in epoch 44=  0.010120882515931457
# total loss= 212.7110337545164
# validation MSE in epoch 45=  0.01186031213413507
# total loss= 213.05170509917662
# validation MSE in epoch 46=  0.008352821039301529
# best_err: 0.008352821039301529 Saving..
# total loss= 211.91964830551296
# validation MSE in epoch 47=  0.010118437300413624
# total loss= 211.98953564558178
# validation MSE in epoch 48=  0.009452864680381116
# total loss= 209.86723659513518
# validation MSE in epoch 49=  0.010126457564281073
# total loss= 210.9966664710082
# validation MSE in epoch 50=  0.008460627513281548
# total loss= 210.62864653067663
# validation MSE in epoch 51=  0.011887259945626907
# total loss= 210.01246183505282
# validation MSE in epoch 52=  0.009965906623446407
# total loss= 210.3899837564677
# validation MSE in epoch 53=  0.0116254113263452
# total loss= 209.31276645557955
# validation MSE in epoch 54=  0.008806486024346938
# total loss= 209.06784535432234
# validation MSE in epoch 55=  0.009773009552516124
# total loss= 209.65992990881205
# validation MSE in epoch 56=  0.008240802020404647
# best_err: 0.008240802020404647 Saving..
# total loss= 207.68993838550523
# validation MSE in epoch 57=  0.008290924174167637
# total loss= 208.45461708353832
# validation MSE in epoch 58=  0.00881036144502119
# total loss= 207.81721966620535
# validation MSE in epoch 59=  0.008226850255159061
# best_err: 0.008226850255159061 Saving..
# total loss= 206.95407805638388
# validation MSE in epoch 60=  0.00840609055456752
# total loss= 207.76407015044242
# validation MSE in epoch 61=  0.010561604333403623
# total loss= 207.0534633230418
# validation MSE in epoch 62=  0.008483931343192442
# total loss= 207.10164860310033
# validation MSE in epoch 63=  0.008790751187036669
# total loss= 206.98642603307962
# validation MSE in epoch 64=  0.009083025430988611
# total loss= 198.4224100196734
# validation MSE in epoch 65=  0.00818468268264624
# best_err: 0.00818468268264624 Saving..
# total loss= 198.46785302041098
# validation MSE in epoch 66=  0.008181165023096858
# best_err: 0.008181165023096858 Saving..
# total loss= 198.37001151684672
# validation MSE in epoch 67=  0.008194498118236969
# total loss= 198.47870404087007
# validation MSE in epoch 68=  0.00819641800057921
# total loss= 198.29334244132042
# validation MSE in epoch 69=  0.008177363086307383
# best_err: 0.008177363086307383 Saving..
# total loss= 198.31062568398193
# validation MSE in epoch 70=  0.008178458234898999
# total loss= 198.14681157376617
# validation MSE in epoch 71=  0.008176903215346473
# best_err: 0.008176903215346473 Saving..
# total loss= 198.20748083479702
# validation MSE in epoch 72=  0.008174299412681238
# best_err: 0.008174299412681238 Saving..
# total loss= 198.26404968858697
# validation MSE in epoch 73=  0.00817007079020204
# best_err: 0.00817007079020204 Saving..
# total loss= 198.20730755012482
# validation MSE in epoch 74=  0.008186221541032337
# total loss= 198.01097809895873
# validation MSE in epoch 75=  0.008179552893873829
# total loss= 198.1998017784208
# validation MSE in epoch 76=  0.008170048414204555
# best_err: 0.008170048414204555 Saving..
# total loss= 198.08254907932132
# validation MSE in epoch 77=  0.008229822343278508
# total loss= 198.09492188505828
# validation MSE in epoch 78=  0.008190820457475273
# total loss= 198.139897656627
# validation MSE in epoch 79=  0.008164243565371827
# best_err: 0.008164243565371827 Saving..
# validation MSE in epoch 79=  0.008164243565371827
# test err= 0.008542892319844588
# start the 4th trial:
# total loss= 722.2054526172578
# validation MSE in epoch 0=  0.013806708449211554
# best_err: 0.013806708449211554 Saving..
# total loss= 401.30409448128194
# validation MSE in epoch 1=  0.02484241658206904
# total loss= 338.4717384427786
# validation MSE in epoch 2=  0.014344687099304856
# total loss= 303.8047315920703
# validation MSE in epoch 3=  0.014515096050206342
# total loss= 294.9326843842864
# validation MSE in epoch 4=  0.010673877677091078
# best_err: 0.010673877677091078 Saving..
# total loss= 281.8341723862104
# validation MSE in epoch 5=  0.0108912872216463
# total loss= 271.86189675796777
# validation MSE in epoch 6=  0.009785753120346425
# best_err: 0.009785753120346425 Saving..
# total loss= 272.2858480364084
# validation MSE in epoch 7=  0.011172352483939878
# total loss= 261.5866723265499
# validation MSE in epoch 8=  0.010032670652011603
# total loss= 263.4083063909784
# validation MSE in epoch 9=  0.009592901868241358
# best_err: 0.009592901868241358 Saving..
# total loss= 255.46403479808941
# validation MSE in epoch 10=  0.010082112316941807
# total loss= 252.90322142001241
# validation MSE in epoch 11=  0.009968345172731125
# total loss= 251.60246129799634
# validation MSE in epoch 12=  0.009606886484882112
# total loss= 244.68003476364538
# validation MSE in epoch 13=  0.009810385744730053
# total loss= 246.13939213007689
# validation MSE in epoch 14=  0.011066046216447807
# total loss= 242.22069395519793
# validation MSE in epoch 15=  0.010500265024563988
# total loss= 238.31260953331366
# validation MSE in epoch 16=  0.014823045966308132
# total loss= 236.2729997127317
# validation MSE in epoch 17=  0.009816810078875705
# total loss= 233.75423637451604
# validation MSE in epoch 18=  0.009285399301098627
# best_err: 0.009285399301098627 Saving..
# total loss= 232.34941338421777
# validation MSE in epoch 19=  0.015265603218364033
# total loss= 230.3802512101829
# validation MSE in epoch 20=  0.008934076773262111
# best_err: 0.008934076773262111 Saving..
# total loss= 227.43204712541774
# validation MSE in epoch 21=  0.00878591740931624
# best_err: 0.00878591740931624 Saving..
# total loss= 227.29571919888258
# validation MSE in epoch 22=  0.013376145086877044
# total loss= 226.83557221386582
# validation MSE in epoch 23=  0.009149926140147457
# total loss= 224.75146439904347
# validation MSE in epoch 24=  0.008766084781076034
# best_err: 0.008766084781076034 Saving..
# total loss= 225.70958534348756
# validation MSE in epoch 25=  0.008735005846047748
# best_err: 0.008735005846047748 Saving..
# total loss= 223.23361667245626
# validation MSE in epoch 26=  0.01142002590431228
# total loss= 221.73792848410085
# validation MSE in epoch 27=  0.01590259639592385
# total loss= 218.92711416305974
# validation MSE in epoch 28=  0.008925716351088984
# total loss= 218.28293243329972
# validation MSE in epoch 29=  0.0085922444925863
# best_err: 0.0085922444925863 Saving..
# total loss= 218.43306000065058
# validation MSE in epoch 30=  0.013876143295981677
# total loss= 215.94387738406658
# validation MSE in epoch 31=  0.010782154139538131
# total loss= 215.19489156408235
# validation MSE in epoch 32=  0.01763259732035239
# total loss= 215.57659834530205
# validation MSE in epoch 33=  0.008809121072548333
# total loss= 213.44369960809126
# validation MSE in epoch 34=  0.008755056088386356
# total loss= 214.6116139376536
# validation MSE in epoch 35=  0.009083403388130497
# total loss= 214.52022918546572
# validation MSE in epoch 36=  0.008447212454790366
# best_err: 0.008447212454790366 Saving..
# total loss= 212.57882444467396
# validation MSE in epoch 37=  0.00983619230308019
# total loss= 212.15902896178886
# validation MSE in epoch 38=  0.010067447920557056
# total loss= 211.64685767423362
# validation MSE in epoch 39=  0.008397944797504771
# best_err: 0.008397944797504771 Saving..
# total loss= 210.99121043318883
# validation MSE in epoch 40=  0.008496056840255043
# total loss= 211.5374016314745
# validation MSE in epoch 41=  0.008668734659676167
# total loss= 211.01894688839093
# validation MSE in epoch 42=  0.008739694567065102
# total loss= 208.85423844959587
# validation MSE in epoch 43=  0.008599059695888036
# total loss= 209.06612931983545
# validation MSE in epoch 44=  0.019577721396558154
# total loss= 208.51615232462063
# validation MSE in epoch 45=  0.008312392998292232
# best_err: 0.008312392998292232 Saving..
# total loss= 208.16235626721755
# validation MSE in epoch 46=  0.011124799922497703
# total loss= 206.72880303440616
# validation MSE in epoch 47=  0.008827656044232333
# total loss= 206.4689070940949
# validation MSE in epoch 48=  0.009129829924353584
# total loss= 206.5143476780504
# validation MSE in epoch 49=  0.009112912249946396
# total loss= 207.41472923057154
# validation MSE in epoch 50=  0.00918675642603477
# total loss= 207.42886474938132
# validation MSE in epoch 51=  0.008403687414032603
# total loss= 206.22141184238717
# validation MSE in epoch 52=  0.011798361600667254
# total loss= 206.21109759109095
# validation MSE in epoch 53=  0.010423682007339195
# total loss= 203.82833924749866
# validation MSE in epoch 54=  0.008285162871899952
# best_err: 0.008285162871899952 Saving..
# total loss= 203.22133026341908
# validation MSE in epoch 55=  0.008462355961073805
# total loss= 205.06509823771194
# validation MSE in epoch 56=  0.008310639210714892
# total loss= 203.36639028135687
# validation MSE in epoch 57=  0.008296078317517693
# total loss= 203.76916359178722
# validation MSE in epoch 58=  0.008377480022329452
# total loss= 204.08804377098568
# validation MSE in epoch 59=  0.008263365101814173
# best_err: 0.008263365101814173 Saving..
# total loss= 203.23564413748682
# validation MSE in epoch 60=  0.009532425281951466
# total loss= 202.53377326065674
# validation MSE in epoch 61=  0.009044026308233094
# total loss= 202.85597879299894
# validation MSE in epoch 62=  0.008590639529149603
# total loss= 202.2056807121262
# validation MSE in epoch 63=  0.008366803284407877
# total loss= 200.77073407778516
# validation MSE in epoch 64=  0.008995970528353776
# total loss= 194.89898806996644
# validation MSE in epoch 65=  0.008177459179020288
# best_err: 0.008177459179020288 Saving..
# total loss= 194.6490630893968
# validation MSE in epoch 66=  0.008170194364735947
# best_err: 0.008170194364735947 Saving..
# total loss= 194.75107701774687
# validation MSE in epoch 67=  0.008145905161589142
# best_err: 0.008145905161589142 Saving..
# total loss= 194.63928851904348
# validation MSE in epoch 68=  0.008152845786760026
# total loss= 194.56360024469905
# validation MSE in epoch 69=  0.008182298754391852
# total loss= 194.63942308630794
# validation MSE in epoch 70=  0.008188934846566976
# total loss= 194.56155451806262
# validation MSE in epoch 71=  0.008149370499415868
# total loss= 194.505703703966
# validation MSE in epoch 72=  0.008153267669642288
# total loss= 194.50551866414025
# validation MSE in epoch 73=  0.008154363090930341
# total loss= 194.4593232960906
# validation MSE in epoch 74=  0.00815025896926436
# total loss= 194.38959531439468
# validation MSE in epoch 75=  0.008141513700131567
# best_err: 0.008141513700131567 Saving..
# total loss= 194.41895236819983
# validation MSE in epoch 76=  0.008142996508142536
# total loss= 194.40506447292864
# validation MSE in epoch 77=  0.008171971142808357
# total loss= 194.42598250415176
# validation MSE in epoch 78=  0.008180981105380337
# total loss= 194.38825345411897
# validation MSE in epoch 79=  0.008138454625721159
# best_err: 0.008138454625721159 Saving..
# validation MSE in epoch 79=  0.008138454625721159
# test err= 0.008224873513815834
# start the 5th trial:
# total loss= 808.0476960726082
# validation MSE in epoch 0=  0.01571191269150287
# best_err: 0.01571191269150287 Saving..
# total loss= 456.215124277398
# validation MSE in epoch 1=  0.01705143012141481
# total loss= 382.20281558763236
# validation MSE in epoch 2=  0.01604950609758627
# total loss= 350.6016238704324
# validation MSE in epoch 3=  0.011462589442588739
# best_err: 0.011462589442588739 Saving..
# total loss= 319.273540077731
# validation MSE in epoch 4=  0.012785563197324571
# total loss= 310.83993849530816
# validation MSE in epoch 5=  0.012714840776501719
# total loss= 296.78900102479383
# validation MSE in epoch 6=  0.011036016266983216
# best_err: 0.011036016266983216 Saving..
# total loss= 287.0705652600154
# validation MSE in epoch 7=  0.010152993138971757
# best_err: 0.010152993138971757 Saving..
# total loss= 279.0773394452408
# validation MSE in epoch 8=  0.010930806118010315
# total loss= 271.50409287167713
# validation MSE in epoch 9=  0.010357337861101884
# total loss= 268.19225762598217
# validation MSE in epoch 10=  0.009819742212194013
# best_err: 0.009819742212194013 Saving..
# total loss= 260.9979738239199
# validation MSE in epoch 11=  0.011041353821712188
# total loss= 256.60818112362176
# validation MSE in epoch 12=  0.009554296721382015
# best_err: 0.009554296721382015 Saving..
# total loss= 252.13987413560972
# validation MSE in epoch 13=  0.013267530716980638
# total loss= 252.41200451366603
# validation MSE in epoch 14=  0.009824298022967169
# total loss= 246.1531413011253
# validation MSE in epoch 15=  0.0092150927375394
# best_err: 0.0092150927375394 Saving..
# total loss= 244.1033559399657
# validation MSE in epoch 16=  0.00959645307596673
# total loss= 241.83817900600843
# validation MSE in epoch 17=  0.010148883883324042
# total loss= 239.67077796487138
# validation MSE in epoch 18=  0.01231316624107459
# total loss= 237.71842873701826
# validation MSE in epoch 19=  0.009481277763377635
# total loss= 234.74943059054203
# validation MSE in epoch 20=  0.009547623125821844
# total loss= 234.32786814006977
# validation MSE in epoch 21=  0.010566987190563702
# total loss= 234.73545045871288
# validation MSE in epoch 22=  0.018038212401190096
# total loss= 229.36645671585575
# validation MSE in epoch 23=  0.00978318565283038
# total loss= 231.05581118445843
# validation MSE in epoch 24=  0.008955613775908863
# best_err: 0.008955613775908863 Saving..
# total loss= 233.0750419567339
# validation MSE in epoch 25=  0.008808693707098799
# best_err: 0.008808693707098799 Saving..
# total loss= 226.20242845406756
# validation MSE in epoch 26=  0.011200268296637755
# total loss= 228.01460597012192
# validation MSE in epoch 27=  0.010284225831719432
# total loss= 228.33691035909578
# validation MSE in epoch 28=  0.00860291457054882
# best_err: 0.00860291457054882 Saving..
# total loss= 227.73519614804536
# validation MSE in epoch 29=  0.009822340002449161
# total loss= 225.65516582876444
# validation MSE in epoch 30=  0.00887441491828117
# total loss= 224.72958079865202
# validation MSE in epoch 31=  0.00862317069071235
# total loss= 222.75262318458408
# validation MSE in epoch 32=  0.008664476278823018
# total loss= 220.9365621143952
# validation MSE in epoch 33=  0.008468892689709767
# best_err: 0.008468892689709767 Saving..
# total loss= 220.25029662065208
# validation MSE in epoch 34=  0.01002727689191722
# total loss= 219.89807298779488
# validation MSE in epoch 35=  0.014858602559123843
# total loss= 219.13149602804333
# validation MSE in epoch 36=  0.00912409542564806
# total loss= 219.99815663229674
# validation MSE in epoch 37=  0.009711811072774261
# total loss= 216.5316804139875
# validation MSE in epoch 38=  0.009158246323805882
# total loss= 218.467405163683
# validation MSE in epoch 39=  0.008466395410306103
# best_err: 0.008466395410306103 Saving..
# total loss= 216.00573709467426
# validation MSE in epoch 40=  0.008763945614534818
# total loss= 214.8224129374139
# validation MSE in epoch 41=  0.009066337480725141
# total loss= 214.56843214994296
# validation MSE in epoch 42=  0.008798896559250416
# total loss= 215.7050726385787
# validation MSE in epoch 43=  0.008311297410036148
# best_err: 0.008311297410036148 Saving..
# total loss= 212.41367190424353
# validation MSE in epoch 44=  0.008502769048477975
# total loss= 212.7032110914588
# validation MSE in epoch 45=  0.008483357710956896
# total loss= 211.3702134117484
# validation MSE in epoch 46=  0.008904441416742931
# total loss= 210.96992697101086
# validation MSE in epoch 47=  0.008903440056453243
# total loss= 211.33482439769432
# validation MSE in epoch 48=  0.008356386603695802
# total loss= 209.62302598869428
# validation MSE in epoch 49=  0.008246390668513438
# best_err: 0.008246390668513438 Saving..
# total loss= 210.08463678974658
# validation MSE in epoch 50=  0.008504473970078563
# total loss= 209.71824386389926
# validation MSE in epoch 51=  0.008134543771861296
# best_err: 0.008134543771861296 Saving..
# total loss= 209.0762909424957
# validation MSE in epoch 52=  0.010171124174164981
# total loss= 207.93269769009203
# validation MSE in epoch 53=  0.009016551607749038
# total loss= 206.4386813682504
# validation MSE in epoch 54=  0.008300743729323764
# total loss= 206.89849901990965
# validation MSE in epoch 55=  0.008272035680461507
# total loss= 207.17400313960388
# validation MSE in epoch 56=  0.009367205018260242
# total loss= 206.0797399226576
# validation MSE in epoch 57=  0.008338439751530759
# total loss= 203.84874593140557
# validation MSE in epoch 58=  0.009248005159611345
# total loss= 205.0166452669073
# validation MSE in epoch 59=  0.00826263443026269
# total loss= 203.81782168662176
# validation MSE in epoch 60=  0.008049150155614648
# best_err: 0.008049150155614648 Saving..
# total loss= 203.85769627755508
# validation MSE in epoch 61=  0.00934642505622601
# total loss= 201.98701296653599
# validation MSE in epoch 62=  0.008456238660992129
# total loss= 204.00460579106584
# validation MSE in epoch 63=  0.008849995456085516
# total loss= 202.2281711853575
# validation MSE in epoch 64=  0.007977735352173616
# best_err: 0.007977735352173616 Saving..
# total loss= 192.9984808121808
# validation MSE in epoch 65=  0.00794989187619829
# best_err: 0.00794989187619829 Saving..
# total loss= 192.8072020956315
# validation MSE in epoch 66=  0.008015752193753816
# total loss= 192.82970974920318
# validation MSE in epoch 67=  0.007993616016515371
# total loss= 192.79054345050827
# validation MSE in epoch 68=  0.007993671125091147
# total loss= 192.81622451823205
# validation MSE in epoch 69=  0.007927460824293115
# best_err: 0.007927460824293115 Saving..
# total loss= 192.6600124272518
# validation MSE in epoch 70=  0.007924026950363832
# best_err: 0.007924026950363832 Saving..
# total loss= 192.59905070625246
# validation MSE in epoch 71=  0.00793811131836467
# total loss= 192.54321815352887
# validation MSE in epoch 72=  0.007966757176829143
# total loss= 192.58092491631396
# validation MSE in epoch 73=  0.007924054729737354
# total loss= 192.4678195551969
# validation MSE in epoch 74=  0.008102517573224393
# total loss= 192.54025829955935
# validation MSE in epoch 75=  0.00792992691741896
# total loss= 192.47989974124357
# validation MSE in epoch 76=  0.00792741781924844
# total loss= 192.44585788156837
# validation MSE in epoch 77=  0.007921324782335266
# best_err: 0.007921324782335266 Saving..
# total loss= 192.5155376382172
# validation MSE in epoch 78=  0.007926620174724803
# total loss= 192.4218824924901
# validation MSE in epoch 79=  0.007928096978490968
# validation MSE in epoch 77=  0.007921324782335266
# test err= 0.008161253176587042
# start the 6th trial:
# total loss= 746.0576487686485
# validation MSE in epoch 0=  0.02019224845388325
# best_err: 0.02019224845388325 Saving..
# total loss= 481.45823341514915
# validation MSE in epoch 1=  0.017205432533848954
# best_err: 0.017205432533848954 Saving..
# total loss= 402.7102911067195
# validation MSE in epoch 2=  0.026530371330699597
# total loss= 360.7268215427175
# validation MSE in epoch 3=  0.011991327598954197
# best_err: 0.011991327598954197 Saving..
# total loss= 342.78184530790895
# validation MSE in epoch 4=  0.015122665930491339
# total loss= 327.0018376391381
# validation MSE in epoch 5=  0.011967922228975908
# best_err: 0.011967922228975908 Saving..
# total loss= 306.38599215075374
# validation MSE in epoch 6=  0.014031083573663608
# total loss= 299.6460684388876
# validation MSE in epoch 7=  0.011885294774422338
# best_err: 0.011885294774422338 Saving..
# total loss= 290.5465144352056
# validation MSE in epoch 8=  0.017051210710053562
# total loss= 280.63902741484344
# validation MSE in epoch 9=  0.010577768022785287
# best_err: 0.010577768022785287 Saving..
# total loss= 275.9566534711048
# validation MSE in epoch 10=  0.014084425053231191
# total loss= 271.35075228707865
# validation MSE in epoch 11=  0.011237830191403012
# total loss= 264.49398320168257
# validation MSE in epoch 12=  0.010420118675189206
# best_err: 0.010420118675189206 Saving..
# total loss= 261.14690455887467
# validation MSE in epoch 13=  0.010431203208988616
# total loss= 256.8658541571349
# validation MSE in epoch 14=  0.011346709895052896
# total loss= 254.53835348086432
# validation MSE in epoch 15=  0.013833478640941706
# total loss= 254.16471037175506
# validation MSE in epoch 16=  0.011705698541501492
# total loss= 248.80060397880152
# validation MSE in epoch 17=  0.01068165984310694
# total loss= 248.1232432476245
# validation MSE in epoch 18=  0.010513442107262556
# total loss= 244.30306369485334
# validation MSE in epoch 19=  0.009740487739451945
# best_err: 0.009740487739451945 Saving..
# total loss= 245.50850512925535
# validation MSE in epoch 20=  0.009453715013134542
# best_err: 0.009453715013134542 Saving..
# total loss= 242.48656419059262
# validation MSE in epoch 21=  0.019305969447727483
# total loss= 240.58524873200804
# validation MSE in epoch 22=  0.009467000199016903
# total loss= 238.80767381330952
# validation MSE in epoch 23=  0.009846849299899084
# total loss= 237.47290832130238
# validation MSE in epoch 24=  0.011280207001244387
# total loss= 235.73474228102714
# validation MSE in epoch 25=  0.009695692876086808
# total loss= 235.67942953063175
# validation MSE in epoch 26=  0.00950526300191643
# total loss= 233.43483217153698
# validation MSE in epoch 27=  0.009657434522125787
# total loss= 231.8645021887496
# validation MSE in epoch 28=  0.01006194981637105
# total loss= 232.6699110143818
# validation MSE in epoch 29=  0.009386459376534246
# best_err: 0.009386459376534246 Saving..
# total loss= 230.66207138076425
# validation MSE in epoch 30=  0.010304336176604962
# total loss= 229.2293059132062
# validation MSE in epoch 31=  0.00996697877493868
# total loss= 228.33213399583474
# validation MSE in epoch 32=  0.00920282677986744
# best_err: 0.00920282677986744 Saving..
# total loss= 227.41058724280447
# validation MSE in epoch 33=  0.009213290355601042
# total loss= 227.21884504077025
# validation MSE in epoch 34=  0.01221171152730419
# total loss= 227.33739059744403
# validation MSE in epoch 35=  0.010258090863524983
# total loss= 225.1055351612158
# validation MSE in epoch 36=  0.009575167324001575
# total loss= 225.31761890323833
# validation MSE in epoch 37=  0.008983211948590612
# best_err: 0.008983211948590612 Saving..
# total loss= 224.86118941986933
# validation MSE in epoch 38=  0.009033628012406217
# total loss= 224.40731973527
# validation MSE in epoch 39=  0.009420977365103075
# total loss= 222.5794683690183
# ...
# validation MSE in epoch 67=  0.008145869898253427
# best_err: 0.008145869898253427 Saving..
# total loss= 198.70978608261794
# validation MSE in epoch 68=  0.008143680065650784
# best_err: 0.008143680065650784 Saving..
# total loss= 198.70382772898301
# validation MSE in epoch 69=  0.008144419430947203
# total loss= 198.66341372183524
# validation MSE in epoch 70=  0.008168366399765122
# total loss= 198.57360564917326
# validation MSE in epoch 71=  0.008150045043472326
# total loss= 198.55954618472606
# validation MSE in epoch 72=  0.008140407786034566
# best_err: 0.008140407786034566 Saving..
# total loss= 198.5700677987188
# validation MSE in epoch 73=  0.008198114806188673
# total loss= 198.48822916904464
# validation MSE in epoch 74=  0.008164056672430307
# total loss= 198.50736942421645
# validation MSE in epoch 75=  0.008138141920597952
# best_err: 0.008138141920597952 Saving..
# total loss= 198.5165848028846
# validation MSE in epoch 76=  0.008149595535636456
# total loss= 198.42133041657507
# validation MSE in epoch 77=  0.008146704273282053
# total loss= 198.5033737742342
# validation MSE in epoch 78=  0.008137191252066318
# best_err: 0.008137191252066318 Saving..
# total loss= 198.44152171490714
# validation MSE in epoch 79=  0.008137677320317126
# validation MSE in epoch 78=  0.008137191252066318
# test err= 0.008421334538518023
# start the 8th trial:
# total loss= 789.8744648993015
# validation MSE in epoch 0=  0.02284604418146712
# best_err: 0.02284604418146712 Saving..
# total loss= 404.9126750761643
# validation MSE in epoch 1=  0.010938081412195252
# best_err: 0.010938081412195252 Saving..
# total loss= 344.7555473493412
# validation MSE in epoch 2=  0.012689303745078082
# total loss= 333.7025301987305
# validation MSE in epoch 3=  0.01064861367832218
# best_err: 0.01064861367832218 Saving..
# total loss= 312.66340118367225
# validation MSE in epoch 4=  0.01234508467148442
# total loss= 293.31524290982634
# validation MSE in epoch 5=  0.02386018273657425
# total loss= 289.1683124168776
# validation MSE in epoch 6=  0.021030352378380305
# total loss= 281.1221218048595
# validation MSE in epoch 7=  0.011899078668893929
# total loss= 264.0007486776449
# validation MSE in epoch 8=  0.009781613640723507
# best_err: 0.009781613640723507 Saving..
# total loss= 260.99514449667186
# validation MSE in epoch 9=  0.010067611856985494
# total loss= 262.0017190040089
# validation MSE in epoch 10=  0.017001966107444567
# total loss= 260.4415287896991
# validation MSE in epoch 11=  0.011133511963911843
# total loss= 256.0619538417086
# validation MSE in epoch 12=  0.010640892055238174
# total loss= 247.8615823732689
# validation MSE in epoch 13=  0.009259081076515541
# best_err: 0.009259081076515541 Saving..
# total loss= 252.22246546810493
# validation MSE in epoch 14=  0.009227209297609682
# best_err: 0.009227209297609682 Saving..
# total loss= 247.1859056511894
# validation MSE in epoch 15=  0.010698600327802602
# total loss= 243.4335051830858
# validation MSE in epoch 16=  0.009518945788510254
# total loss= 244.39393913187087
# validation MSE in epoch 17=  0.01021838995309613
# total loss= 242.52873869985342
# validation MSE in epoch 18=  0.01044408038018157
# total loss= 238.64508472476155
# validation MSE in epoch 19=  0.011083543463454013
# total loss= 236.83952413266525
# validation MSE in epoch 20=  0.008899528169144732
# best_err: 0.008899528169144732 Saving..
# total loss= 234.0125393080525
# validation MSE in epoch 21=  0.009218833117460993
# total loss= 233.74742865515873
# validation MSE in epoch 22=  0.00911527364036859
# total loss= 232.5889248517342
# validation MSE in epoch 23=  0.009586976053982843
# total loss= 232.7748665418476
# validation MSE in epoch 24=  0.013674912187489362
# total loss= 226.0804964848794
# validation MSE in epoch 25=  0.008978892806984672
# total loss= 229.03671162715182
# validation MSE in epoch 26=  0.008786136328779226
# best_err: 0.008786136328779226 Saving..
# total loss= 227.27175896428525
# validation MSE in epoch 27=  0.010462835298533167
# total loss= 230.25685531599447
# validation MSE in epoch 28=  0.008634074407801619
# best_err: 0.008634074407801619 Saving..
# total loss= 225.3058315543458
# validation MSE in epoch 29=  0.00894722517876626
# total loss= 223.26836646301672
# validation MSE in epoch 30=  0.009315383086454597
# total loss= 225.76076171686873
# validation MSE in epoch 31=  0.01427978047041502
# total loss= 224.72912855190225
# validation MSE in epoch 32=  0.008955172110467096
# total loss= 223.02207865659148
# validation MSE in epoch 33=  0.008687459212120732
# total loss= 220.586597208865
# validation MSE in epoch 34=  0.009297643720134882
# total loss= 222.11659122537822
# validation MSE in epoch 35=  0.00896489462726848
# total loss= 220.7771919965744
# validation MSE in epoch 36=  0.00905229545770191
# total loss= 223.1811366621405
# validation MSE in epoch 37=  0.008629377084208318
# best_err: 0.008629377084208318 Saving..
# total loss= 220.4554473881144
# validation MSE in epoch 38=  0.01009541301944357
# total loss= 220.0840033055283
# validation MSE in epoch 39=  0.008813662920867646
# total loss= 218.88771195849404
# validation MSE in epoch 40=  0.009929009284315003
# total loss= 218.23796818824485
# validation MSE in epoch 41=  0.012229814250219101
# total loss= 215.67167860781774
# validation MSE in epoch 42=  0.008581331460710275
# best_err: 0.008581331460710275 Saving..
# total loss= 216.0304518993944
# validation MSE in epoch 43=  0.010243140143986413
# total loss= 216.36956762103364
# validation MSE in epoch 44=  0.009292622375837082
# total loss= 217.15574548579752
# validation MSE in epoch 45=  0.008614598155740212
# total loss= 214.951370830182
# validation MSE in epoch 46=  0.011072490715120101
# total loss= 215.1480863899924
# validation MSE in epoch 47=  0.008721213401203985
# total loss= 214.00888749025762
# validation MSE in epoch 48=  0.009223347976698111
# total loss= 211.4557511820458
# validation MSE in epoch 49=  0.008426493685968728
# best_err: 0.008426493685968728 Saving..
# total loss= 213.01032189140096
# validation MSE in epoch 50=  0.008868765465921448
# total loss= 212.21177412662655
# validation MSE in epoch 51=  0.008392926228562655
# best_err: 0.008392926228562655 Saving..
# total loss= 210.49845816474408
# validation MSE in epoch 52=  0.00855893097097912
# total loss= 210.3769555441104
# validation MSE in epoch 53=  0.008422742009858392
# total loss= 210.46678509749472
# validation MSE in epoch 54=  0.008876135723968913
# total loss= 208.7269886978902
# validation MSE in epoch 55=  0.009155790824294206
# total loss= 210.25224635191262
# validation MSE in epoch 56=  0.008636096710350717
# total loss= 208.57748441956937
# validation MSE in epoch 57=  0.00837748975051368
# best_err: 0.00837748975051368 Saving..
# total loss= 209.03728484269232
# validation MSE in epoch 58=  0.008250271537112549
# best_err: 0.008250271537112549 Saving..
# total loss= 207.806672220584
# validation MSE in epoch 59=  0.01160250002947694
# total loss= 209.14151137601584
# validation MSE in epoch 60=  0.016245961664297367
# total loss= 209.73516305861995
# validation MSE in epoch 61=  0.008366593532936667
# total loss= 207.10404435452074
# validation MSE in epoch 62=  0.010951913749850046
# total loss= 207.95136854052544
# validation MSE in epoch 63=  0.008565945324572999
# total loss= 206.82279186230153
# validation MSE in epoch 64=  0.00834334267905177
# total loss= 195.0984035229776
# validation MSE in epoch 65=  0.008152783089334193
# best_err: 0.008152783089334193 Saving..
# total loss= 195.12910473672673
# validation MSE in epoch 66=  0.008210311971231142
# total loss= 194.9816965176724
# validation MSE in epoch 67=  0.008125763243715585
# best_err: 0.008125763243715585 Saving..
# total loss= 195.03641204349697
# validation MSE in epoch 68=  0.008125293314987203
# best_err: 0.008125293314987203 Saving..
# total loss= 194.8842476583086
# validation MSE in epoch 69=  0.008122942131889245
# best_err: 0.008122942131889245 Saving..
# total loss= 194.95704357512295
# validation MSE in epoch 70=  0.008163290668618513
# total loss= 194.73391927219927
# validation MSE in epoch 71=  0.00814426547825834
# total loss= 194.82599122310057
# validation MSE in epoch 72=  0.008145854334743687
# total loss= 194.82620827993378
# validation MSE in epoch 73=  0.00813366476773722
# total loss= 194.96693265298381
# validation MSE in epoch 74=  0.008137243060666977
# total loss= 194.87488959473558
# validation MSE in epoch 75=  0.008174869088687064
# total loss= 194.69653315562755
# validation MSE in epoch 76=  0.008116837542001187
# best_err: 0.008116837542001187 Saving..
# total loss= 194.67231101123616
# validation MSE in epoch 77=  0.008213027218301973
# total loss= 194.71858502179384
# validation MSE in epoch 78=  0.008116352568678807
# best_err: 0.008116352568678807 Saving..
# total loss= 194.72067551873624
# validation MSE in epoch 79=  0.008116740589471974
# validation MSE in epoch 78=  0.008116352568678807
# test err= 0.008327112337030481
# start the 9th trial:
# total loss= 819.7926321234554
# validation MSE in epoch 0=  0.019664308810323217
# best_err: 0.019664308810323217 Saving..
# total loss= 401.7823743550107
# validation MSE in epoch 1=  0.01119077312599151
# best_err: 0.01119077312599151 Saving..
# total loss= 340.96933580189943
# validation MSE in epoch 2=  0.011502260489815817
# total loss= 298.82714872062206
# validation MSE in epoch 3=  0.013016946593615552
# total loss= 291.84688915498555
# validation MSE in epoch 4=  0.010899803819866825
# best_err: 0.010899803819866825 Saving..
# total loss= 287.7775634662248
# validation MSE in epoch 5=  0.009529560627012315
# best_err: 0.009529560627012315 Saving..
# total loss= 274.0496661439538
# validation MSE in epoch 6=  0.01774468073307269
# total loss= 264.34932523872703
# validation MSE in epoch 7=  0.01202479465453933
# total loss= 257.7133092409931
# validation MSE in epoch 8=  0.009812283096474785
# total loss= 252.72653648722917
# validation MSE in epoch 9=  0.011088108348738461
# total loss= 248.0531958444044
# validation MSE in epoch 10=  0.01137554170246812
# total loss= 246.85163460485637
# validation MSE in epoch 11=  0.008993280752643159
# best_err: 0.008993280752643159 Saving..
# total loss= 246.25446234783158
# validation MSE in epoch 12=  0.010461214341138225
# total loss= 240.62430258840322
# validation MSE in epoch 13=  0.008754855338599323
# best_err: 0.008754855338599323 Saving..
# total loss= 237.4086557473056
# validation MSE in epoch 14=  0.012287070237790812
# total loss= 235.10174098378047
# validation MSE in epoch 15=  0.01438441725069289
# total loss= 234.0507774334401
# validation MSE in epoch 16=  0.010988050198317912
# total loss= 230.18728319276124
# validation MSE in epoch 17=  0.009161446798223448
# total loss= 230.44603788293898
# validation MSE in epoch 18=  0.00857431991873554
# best_err: 0.00857431991873554 Saving..
# total loss= 227.42818083846942
# validation MSE in epoch 19=  0.010301952700533142
# total loss= 227.05611973581836
# validation MSE in epoch 20=  0.008743999068588767
# total loss= 224.1775628873147
# validation MSE in epoch 21=  0.008450054250779557
# best_err: 0.008450054250779557 Saving..
# total loss= 221.89872153149918
# validation MSE in epoch 22=  0.01189629279980998
# total loss= 219.85389456897974
# validation MSE in epoch 23=  0.012121056079482174
# total loss= 220.56469219457358
# validation MSE in epoch 24=  0.009039279639883262
# total loss= 218.60900781070814
# validation MSE in epoch 25=  0.008424270496563914
# best_err: 0.008424270496563914 Saving..
# total loss= 218.8281943537295
# validation MSE in epoch 26=  0.008342679239179826
# best_err: 0.008342679239179826 Saving..
# total loss= 218.17743826424703
# validation MSE in epoch 27=  0.008337102951388278
# best_err: 0.008337102951388278 Saving..
# total loss= 218.17408492416143
# validation MSE in epoch 28=  0.008597505108074848
# total loss= 214.83806224912405
# validation MSE in epoch 29=  0.008269033133104644
# best_err: 0.008269033133104644 Saving..
# total loss= 215.74757157312706
# validation MSE in epoch 30=  0.008393668316680767
# total loss= 213.71745392866433
# validation MSE in epoch 31=  0.008634410035756117
# total loss= 213.62160361371934
# validation MSE in epoch 32=  0.008298670819731426
# total loss= 212.83248002640903
# validation MSE in epoch 33=  0.010663369420748693
# total loss= 212.40905758622102
# validation MSE in epoch 34=  0.00885178765441498
# total loss= 211.02575297281146
# validation MSE in epoch 35=  0.00848793698515111
# total loss= 210.1473637642339
# validation MSE in epoch 36=  0.008624984940769494
# total loss= 210.2337545021437
# validation MSE in epoch 37=  0.008223861698294178
# best_err: 0.008223861698294178 Saving..
# total loss= 208.3287450140342
# validation MSE in epoch 38=  0.009611280278848843
# total loss= 209.69140184065327
# validation MSE in epoch 39=  0.008501951302888756
# total loss= 208.04634565860033
# validation MSE in epoch 40=  0.009584426233384522
# total loss= 208.62834606412798
# validation MSE in epoch 41=  0.00817320138162464
# best_err: 0.00817320138162464 Saving..
# total loss= 207.4004849884659
# validation MSE in epoch 42=  0.008361164398915016
# total loss= 207.17613145289943
# validation MSE in epoch 43=  0.008306934176382232
# total loss= 206.7202682318166
# validation MSE in epoch 44=  0.008644687160854375
# total loss= 205.3740585418418
# validation MSE in epoch 45=  0.010855666429713145
# total loss= 205.53362369188108
# validation MSE in epoch 46=  0.00919217587368925
# total loss= 204.5965533745475
# validation MSE in epoch 47=  0.008289004328238954
# total loss= 204.4047078359872
# validation MSE in epoch 48=  0.00818271955093124
# total loss= 204.79125043796375
# validation MSE in epoch 49=  0.008175971581950754
# total loss= 204.16016111243516
# validation MSE in epoch 50=  0.010033231173114119
# total loss= 203.20754635473713
# validation MSE in epoch 51=  0.008046531055531839
# best_err: 0.008046531055531839 Saving..
# total loss= 203.17535344557837
# validation MSE in epoch 52=  0.008789722283446202
# total loss= 203.14528124849312
# validation MSE in epoch 53=  0.009387756310462906
# total loss= 204.54285201523453
# validation MSE in epoch 54=  0.008308895108243907
# total loss= 202.17292785923928
# validation MSE in epoch 55=  0.008074171957499845
# total loss= 201.65922297770157
# validation MSE in epoch 56=  0.009561146281913208
# total loss= 201.79366570245475
# validation MSE in epoch 57=  0.008802026141960368
# total loss= 201.74134340928867
# validation MSE in epoch 58=  0.00855257035335867
# total loss= 202.02146005583927
# validation MSE in epoch 59=  0.010185552643042379
# total loss= 201.44547797832638
# validation MSE in epoch 60=  0.011343358092004258
# total loss= 201.1543485573493
# validation MSE in epoch 61=  0.010027913305242732
# total loss= 199.64591958606616
# validation MSE in epoch 62=  0.009046199150833044
# total loss= 200.2390323835425
# validation MSE in epoch 63=  0.008184229050892155
# total loss= 200.14638407086022
# validation MSE in epoch 64=  0.008254924355650655
# total loss= 192.0114940535277
# validation MSE in epoch 65=  0.008026838187097566
# best_err: 0.008026838187097566 Saving..
# total loss= 191.96547826007009
# validation MSE in epoch 66=  0.007971303979493966
# best_err: 0.007971303979493966 Saving..
# total loss= 191.84374675527215
# validation MSE in epoch 67=  0.007966332310676678
# best_err: 0.007966332310676678 Saving..
# total loss= 191.84097518888302
# validation MSE in epoch 68=  0.007986105801434365
# total loss= 191.71336002321914
# validation MSE in epoch 69=  0.008009200685805497
# total loss= 191.74336323491298
# validation MSE in epoch 70=  0.008030153145147137
# total loss= 191.7580031589605
# validation MSE in epoch 71=  0.0079654105931166
# best_err: 0.0079654105931166 Saving..
# total loss= 191.81207373552024
# validation MSE in epoch 72=  0.007967091540305511
# total loss= 191.8404763005674
# validation MSE in epoch 73=  0.007966070601168123
# total loss= 191.72900763945654
# validation MSE in epoch 74=  0.008011322044644961
# total loss= 191.582330272533
# validation MSE in epoch 75=  0.007978263093567348
# total loss= 191.67856346303597
# validation MSE in epoch 76=  0.00796186715868062
# best_err: 0.00796186715868062 Saving..
# total loss= 191.70186575269327
# validation MSE in epoch 77=  0.008002106920871721
# total loss= 191.66144363116473
# validation MSE in epoch 78=  0.007964926281122105
# total loss= 191.45150245400146
# validation MSE in epoch 79=  0.008036365972706004
# validation MSE in epoch 76=  0.00796186715868062
# test err= 0.008150582461593515

# %% [markdown]
# # Results

# %% [markdown]
# ## 1. plot the training and validation and testing chart

# %%
def plott(x, ti):
    """
    A method to plot training process.
    ...
    Parameters
    ----------
    x : nparray.
        the data to plot with shape of (800,1).
    ti : str
        The title of the plot.
    """
    plt.figure(figsize=(7,5))
    index = 0
    for i in range(0, 9):
        t = x[index: index+80]
        index=index+80
        plt.plot(t, label=f'trail {i}')
    plt.title(f'{ti} MSE in different trails')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.legend()
    plt.grid()

# %%
def plott_20(x, ti):
    """
    A method to plot training process in the last 20 epoch.
    ...
    Parameters
    ----------
    x : nparray.
        the data to plot with shape of (800, ).
    ti : str
        The title of the plot.
    """
    plt.figure(figsize=(7,5))
    index = 0
    for i in range(0, 9):
        t = x[index+59: index+80]
        index=index+80
        plt.plot(t, label=f'trail {i}')
    plt.title(f'{ti} MSE in different trails(last 20 epoch)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# training 
x = np.array(train_trails)
plott(x, "training")

# %%
# training 
x = np.array(train_trails)
plott_20(x, "training")

# %%
# validation
x = np.array(validate_trails)
plott(x, "validation")

# %%
# validation
x = np.array(validate_trails)
plott_20(x, "validation")

# %%
# testing 
x = np.array(test_trails)
plott(x, "testing")

# %%
# testng
x =  np.array(test_trails)
plott_20(x, "testing")

# %% [markdown]
# ## 2. plot the best velidation MSE and testing MSE

# %%
x = vali
plt.figure(figsize=(7,5))
plt.title('validation performance')
plt.plot(x, label='validation MSE',marker='o')
plt.plot([], [], ' ', label=f"mean={round(np.mean(x),6)}")
plt.plot([], [], ' ', label=f"std={round(np.std(x),6)}")
plt.xlabel('Trail')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
print("validation mean=",np.mean(x))
print("validation std=",np.std(x))
# Out:
# validation mean= 0.008100089010435036
# validation std= 0.00018932220156857708

# %%
x = testing
plt.figure(figsize=(7,5))
plt.title('testing performance')
plt.plot(x, label='testing MSE',marker='o')
plt.plot([], [], ' ', label=f"mean={round(np.mean(x),6)}")
plt.plot([], [], ' ', label=f"std={round(np.std(x),6)}")
plt.xlabel('Trail')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()
print("testing mean=",np.mean(x))
print("testing std=",np.std(x))
# Out:
# testing mean= 0.008350459666273392
# testing std= 0.00021941579626518797

# %%
x1 = vali
x2 = testing
plt.figure(figsize=(7,5))
plt.title('Two in one')
plt.plot(x1, label='vaidation_MSE',marker='o')
plt.plot(x2, label='tesing_MSE',marker='o')
plt.xlabel('Trail')
plt.ylabel('MSE')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Save csv

# %%
x1 = np.array(vali).reshape(1, -1)
x2 = np.array(testing).reshape(1, -1)
two = np.vstack((x1,x2))
df = pd.DataFrame(two).T
df.to_csv(os.path.join(os.getcwd(),"training_process") + "\\s2_no_pe.csv")

# %%
# save data 
x1 = np.array(train_trails).reshape(1, -1)
x2 = np.array(validate_trails).reshape(1, -1)
x3 = np.array(test_trails).reshape(1, -1)
three = np.vstack((x1,x2,x3))
df = pd.DataFrame(three).T
df.to_csv(os.path.join(os.getcwd(),"training_process") + "\\s2_no_pe_process.csv")
